# %%
import pandas as pd
import os
from collections import defaultdict
import numpy as np
import re
import glob

# %%
def def_value(): 
    return 0


def calc_interval(bottom, top):
    
    notes = {
        "C":0,
        "D":1,
        "E":2,
        "F":3,
        "G":4,
        "A":5,
        "B":6
    }

    clockVals = {
        "C": 0,
        "D": 2,
        "E": 4,
        "F": 5,
        "G": 7,
        "A": 9,
        "B": 11
    }

    intervalToClock = [0, 2, 4, 5, 7, 9, 11]

    accidentals = defaultdict(def_value)
    accidentals["--"] = -2
    accidentals["-"] = -1
    accidentals["#"] =  1
    accidentals["##"] = 2    

    bottomNote = re.match("[A-G]", bottom).group()
    topNote = re.match("([A-G])", top).group()
    bAccMatch = re.search("[-#]+", bottom)
    tAccMatch = re.search("[-#]+", top)
    

    bottomAcc = bAccMatch.group() if bAccMatch else " "
    topAcc = tAccMatch.group() if tAccMatch else " "

    bottomInd = notes[bottomNote]
    topInd = notes[topNote]
    noteInterval = (topInd - bottomInd) % 7 + 1

    bottomClock = clockVals[bottomNote] + accidentals[bottomAcc];
    topClock = clockVals[topNote] + accidentals[topAcc];
    clockValue = topClock - bottomClock;

    if clockValue < 0:
        clockValue += 12

    noteToClock = intervalToClock[noteInterval - 1];
    diff = clockValue - noteToClock;

    #The most we'd expect to have to alter an interval is by 6 semitones;
    # otherwise, something is wrong.
    if abs(diff) > 6:
        if diff > 0:
            diff -= 12
        else:
            diff += 12

    ss = "";
    if diff > 0:
        ss = "#"*diff
    elif diff < 0:
        ss = "b" * (-1*diff)
        
    return ss + str(noteInterval)

# %%
calc_interval("C##", "G--")
# Out:
# 'bbbb5'

# %%
files = os.listdir()
files
# Out:
# ['MichaelJackson_HumanNature_1983.harm',
#  'TheBabys_EveryTimeIThinkOfYou_1979.harm',
#  'Chicago_25Or6To4_1970.hum',
#  'KoolAndTheGang_JungleBoogie_1974.hum',
#  'GladysKnightAndThePips_BestThingThatEverHappenedToMe_1974.harm',
#  'FloydCramer_LastDate_1960.harm',
#  'MarvinGaye_MercyMercyMe_1971.hum',
#  'CrosbyStillsAndNash_SuiteJudyBlueEyes_1969.harm',
#  'TheRollingStones_ItsOnlyRockNRoll_1974.harm',
#  'FatsDomino_IWantToWalkYouHome_1959.harm',
#  'BrotherJackMcDuff_ThemeFromElectricSurfboard_1969.harm',
#  'PatBenatar_LittleTooLate_1983.harm',
#  'CheapTrick_IWantYouToWantMe_1979.harm',
#  'Commodores_Lady_1981.hum',
#  'Madonna_LiveToTell_1986.harm',
#  'RickSpringfield_JessiesGirl_1981.harm',
#  'BruceSpringsteen_ImGoinDown_1985.hum',
#  'AlanODay_UndercoverAngel_1977.harm',
#  'CheapTrick_Surrender_1978.harm',
#  'WilsonPhillips_HoldOn_1990.hum',
#  'DinahWashington_WhereAreYou_1962.harm',
#  'Shannon_LetTheMusicPlay_1984.harm',
#  'WilsonPickett_DontKnockMyLovePt1_1971.harm',
#  'ChrisKenner_LandOf1000Dances_1963.harm',
#  'BingCrosby_SilentNight_1960.hum',
#  'Level42_SomethingAboutYou_1986.hum',
#  'JohnnyTillotson_ItKeepsRightOnAHurtin_1962.harm',
#  'CoreyHart_InYourSoul_1988.harm',
#  'JerryJeffWalker_MrBojangles_1968.hum',
#  'BarbraStreisand_FunnyGirl_1964.harm',
#  'DrHook_YearsFromNow_1980.harm',
#  'BillyIdol_FleshForFantasy_1984.harm',
#  'Dion_RunaroundSue_1961.harm',
#  'NakedEyes_AlwaysSomethingThereToRemindMe_1983.hum',
#  'Chicago_AliveAgain_1978.harm',
#  'TheBeachBoys_SailOnSailor_1975.harm',
#  'JoeCocker_WithALittleHelpFromMyFriends_1968.harm',
#  'RodBernard_ThisShouldGoOnForever_1959.harm',
#  'Dion_RubyBaby_1963.harm',
#  'BrownsvilleStation_SmokinInTheBoysRoom_1973.harm',
#  'NatKingCole_ThoseLazyHazyCrazyDaysOfSummer_1963.harm',
#  'Focus_HocusPocus_1973.harm',
#  'PeterGabriel_ShockTheMonkey_1982.hum',
#  'JohnnyTillotson_OutOfMyMind_1963.harm',
#  'TheYoungbloods_GetTogether_1969.harm',
#  'DonnaFargo_Superman_1973.harm',
#  'IsaacHayes_DoYourThing_1972.harm',
#  'JimiHendrix_Freedom_1971.harm',
#  'RayCharles_EleanorRigby_1968.harm',
#  'BonniePointer_HeavenMustHaveSentYou_1979.harm',
#  'TheHollies_LongDarkRoad_1972.harm',
#  'BillWithers_AintNoSunshine_1971.harm',
#  'EltonJohn_Levon_1971.harm',
#  'TheBeatles_LoveMeDo_1964.hum',
#  'LedZeppelin_DyerMaker_1973.hum',
#  'TheIsleyBrothers_ItsYourThing_1969.harm',
#  'AaronNeville_TellItLikeItIs_1966.harm',
#  'JackieWilson_BabyWorkout_1963.harm',
#  'TheDoors_RidersOnTheStorm_1971.hum',
#  'PaulMcCartney_WithALittleLuck_1978.harm',
#  'TheDrifters_OnBroadway_1963.harm',
#  'TheKinks_BetterThings_1981.hum',
#  'BrendaLee_AllAloneAmI_1962.harm',
#  'BillyIdol_RebelYell_1984.hum',
#  'TomJones_ShesALady_1971.hum',
#  'BobSeger_AgainstTheWind_1980.harm',
#  'KennyRogers_ScarletFever_1983.harm',
#  'BillySquier_DontSayYouLoveMe_1989.harm',
#  'LedZeppelin_OverTheHillsAndFarAway_1973.hum',
#  'BobbiMartin_ILoveYouSo_1965.harm',
#  'BarbraStreisand_People_1964.harm',
#  'ToddRundgren_ADreamGoesOnForever_1974.harm',
#  'Sting_IfYouLoveSomebodySetThemFree_1985.harm',
#  'U2_WithOrWithoutYou_1987.hum',
#  'GeorgeHarrison_ThisSong_1977.harm',
#  'DuranDuran_IDontWantYourLove_1989.harm',
#  'TheWeatherGirls_ItsRainingMen_1983.hum',
#  'FreddieJackson_HaveYouEverLovedSomebody_1987.harm',
#  'CannedHeat_LetsWorkTogether_1970.harm',
#  'GinoVannelli_BlackCars_1985.harm',
#  'BruceSpringsteen_MyHometown_1985.hum',
#  'TheBeatles_ObLaDiObLaDa_1976.hum',
#  'ThePowerStation_SomeLikeItHot_1985.harm',
#  'Chicago_DoesAnybodyReallyKnowWhatTimeItIs_1970.hum',
#  'LittleRiverBand_WeTwo_1983.harm',
#  'Bread_SweetSurrender_1972.harm',
#  'JamesTaylor_CountryRoad_1971.harm',
#  'GloriaGaynor_NeverCanSayGoodbye_1975.hum',
#  'RodStewart_MaggieMay_1971.harm',
#  'LittleAnthonyAndTheImperials_OutOfSightOutOfMind_1969.harm',
#  'CultureClub_IllTumble4Ya_1983.harm',
#  'BobSeger_RockAndRollNeverForgets_1977.harm',
#  'RobertPalmer_AddictedToLove_1986.harm',
#  'ThelmaHouston_DontLeaveMeThisWay_1977.harm',
#  'The5thDimension_IfICouldReachYou_1972.hum',
#  'BadCompany_RockNRollFantasy_1979.harm',
#  'IsaacHayes_TheLookOfLove_1971.harm',
#  'RayParkerJr_Ghostbusters_1984.harm',
#  'SwinginMedallions_DoubleShot_1966.harm',
#  'MichaelJackson_BeatIt_1983.hum',
#  'Dion_AbrahamMartinAndJohn_1968.harm',
#  'Whitesnake_HereIGoAgain_1987.hum',
#  'TheRollingStones_Dandelion_1967.harm',
#  'ChuckBerry_SweetLittleRockAndRoll_1958.harm',
#  'MichaelJackson_WannaBeStartinSomethin_1983.harm',
#  'JesusJones_RightHereRightNow_1991.harm',
#  'CrosbyStillsAndNash_GotItMade_1989.harm',
#  'MaxFrostAndTheTroopers_ShapeOfThingsToCome_1968.harm',
#  'HueyLewis_IWantANewDrug_1984.harm',
#  'EricClapton_LetItRain_1972.hum',
#  'DavidCrosbyAndGrahamNash_CarryMe_1975.harm',
#  'BobbyWomack_ThatsTheWayIFeelAboutCha_1971.harm',
#  'JohnnyCash_IGotStripes_1959.hum',
#  'TheBeachBoys_BluebirdsOverTheMountain_1969.harm',
#  'RoyDrusky_ThreeHeartsInATangle_1961.harm',
#  'SantoAndJohnny_SleepWalk_1959.harm',
#  'LeoSayer_YouMakeMeFeelLikeDancing_1977.hum',
#  'FatsDomino_BeMyGuest_1959.hum',
#  'EltonJohn_GoodbyeYellowBrickRoad_1973.hum',
#  'Dion_BornToCry_1962.harm',
#  'ChuckBerry_AlmostGrown_1959.hum',
#  'SoftCell_TaintedLove_1982.hum',
#  'TheEverlyBrothers_OnTheWingsOfANightingale_1984.harm',
#  'TheDramatics_HeyYouGetOffMyMountain_1973.harm',
#  'GordonLightfoot_Beautiful_1972.harm',
#  'AnitaBaker_GivingYouTheBestThatIGot_1989.harm',
#  'WaylonJennings_ThemeFromTheDukesOfHazzard_1980.harm',
#  'TheRollingStones_HonkyTonkWomen_1969.hum',
#  'RandyVanwarmer_JustWhenINeededYouMost_1979.harm',
#  'TheBeachBoys_StillCruisin_1989.harm',
#  'TheSupremes_FloyJoy_1972.harm',
#  'BachmanTurnerOverdrive_RollOnDownTheHighway_1975.hum',
#  'FlattAndScruggs_FoggyMountainBreakdown_1968.harm',
#  'TheSopwithCamel_HelloHello_1967.harm',
#  'TenYearsAfter_IdLoveToChangeTheWorld_1971.harm',
#  'ArethaFranklin_ChainOfFools_1967.harm',
#  'DavidBowie_BlueJean_1984.hum',
#  'JimmyCliff_WonderfulWorldBeautifulPeople_1969.harm',
#  'CultureClub_KarmaChameleon_1984.hum',
#  'RunDMC_WalkThisWay_1986.harm',
#  'PaulRevereAndTheRaiders_Kicks_1966.hum',
#  'JohnnyTillotson_JimmysGirl_1961.harm',
#  'Heart_TheresTheGirl_1988.harm',
#  'Steppenwolf_BornToBeWild_1968.hum',
#  'TheShirelles_WillYouLoveMeTomorrow_1961.hum',
#  'TheFireballs_SugarShack_1963.harm',
#  'JeffersonStarship_CountOnMe_1978.harm',
#  'ThePolice_EveryLittleThingSheDoesIsMagic_1981.harm',
#  'DeanMartin_IWill_1965.harm',
#  'WildCherry_PlayThatFunkyMusic_1976.harm',
#  'BobSeger_LikeARock_1986.hum',
#  'JacksonBrowne_RedneckFriend_1973.harm',
#  'PatrickHernandez_BornToBeAlive_1979.harm',
#  'ArthurConley_SweetSoulMusic_1967.harm',
#  'IronButterfly_InAGaddaDaVida_1968.harm',
#  'TheChiffons_HesSoFine_1963.hum',
#  'PatBenatar_LoveIsABattlefield_1983.harm',
#  'EarthWindAndFire_Getaway_1976.harm',
#  'TheBeatles_Help_1965.hum',
#  'IkeAndTinaTurner_IWantToTakeYouHigher_1970.harm',
#  'DeLaSoul_MeMyselfAndI_1989.harm',
#  'RobBase_ItTakesTwo_1988.harm',
#  'TheBeachBoys_Kokomo_1988.hum',
#  'GeneralPublic_Tenderness_1984.harm',
#  'TheTurtles_HappyTogether_1967.hum',
#  'TanyaTucker_HeresSomeLove_1976.harm',
#  'The5thDimension_IDidntGetToSleepAtAll_1972.harm',
#  'Genesis_TonightTonightTonight_1987.harm',
#  'ChubbyChecker_TheTwist_1962.hum',
#  'Chicago_FeelinStrongerEveryDay_1973.hum',
#  'TomTHall_ILove_1973.harm',
#  'TheLas_ThereSheGoes_1991.hum',
#  'ElvisPresley_GuitarMan_1968.hum',
#  'MarkyMark_GoodVibrations_1991.hum',
#  'JamesBrown_ColdSweatPart1_1967.hum',
#  'UB40_TheWayYouDoTheThingsYouDo_1990.harm',
#  'ABBA_Chiquitita_1979.hum',
#  'RobertJohn_LonelyEyes_1980.harm',
#  'ElvisPresley_IfICanDream_1968.harm',
#  'TheRighteousBrothers_SoulAndInspiration_1966.harm',
#  'SimonAndGarfunkel_TheSoundsOfSilence_1965.hum',
#  'CliffRichard_Carrie_1980.harm',
#  'TracyChapman_BabyCanIHoldYou_1989.harm',
#  'HiFive_ILikeTheWay_1991.harm',
#  'KennyRogers_Lucille_1977.harm',
#  'ElvisPresley_SheThinksIStillCare_1977.harm',
#  'MarcCohn_WalkingInMemphis_1991.harm',
#  'BillyIdol_CatchMyFall_1985.harm',
#  'DeanMartin_EverybodyLovesSomebody_1964.harm',
#  'MartyRobbins_IWalkAlone_1968.harm',
#  'SimonAndGarfunkel_AHazyShadeOfWinter_1966.hum',
#  'TheKendalls_HeavensJustASinAway_1977.hum',
#  'DoubleExposure_TenPercent_1976.harm',
#  'GrandFunkRailroad_WalkLikeAMan_1973.harm',
#  'BobSeger_NightMoves_1977.harm',
#  'DrHook_WalkRightIn_1977.harm',
#  'JamesBrown_GetUp_1970.hum',
#  'TinaTurner_WeDontNeedAnotherHero_1985.hum',
#  'Poison_UnskinnyBop_1990.harm',
#  'CyndiLauper_IDroveAllNight_1989.harm',
#  'JacksonBrowne_Boulevard_1980.harm',
#  'TheRollingStones_HaveYouSeenYourMotherBabyStandingInTheShadow_1966.harm',
#  'ArethaFranklin_INeverLovedAMan_1967.harm',
#  'MilliVanilli_BabyDontForgetMyNumber_1989.hum',
#  'UrbanDanceSquad_DeeperShadeOfSoul_1991.harm',
#  'AnitaBaker_SweetLove_1986.hum',
#  'Debarge_TimeWillReveal_1984.harm',
#  'BJThomas_HookedOnAFeeling_1968.harm',
#  'TheBand_LifeIsACarnival_1971.harm',
#  'SimpleMinds_SanctifyYourself_1986.hum',
#  'ElvisPresley_HisLatestFlame_1961.harm',
#  'TheElectricPrunes_IHadTooMuchToDream_1967.hum',
#  'TheTemptations_IWishItWouldRain_1968.harm',
#  'JudasPriest_YouveGotAnotherThingComin_1982.hum',
#  'EddieRabbitt_ILoveARainyNight_1981.harm',
#  'Blondie_OneWayOrAnother_1979.hum',
#  'CharlieRich_LonelyWeekends_1960.harm',
#  'MaryMacGregor_TornBetweenTwoLovers_1976.harm',
#  'Rockwell_SomebodysWatchingMe_1984.hum',
#  'EricCarmen_HungryEyes_1988.harm',
#  'Firehouse_DontTreatMeBad_1991.harm',
#  'TheRighteousBrothers_UnchainedMelody_1965.hum',
#  'Genesis_InvisibleTouch_1986.harm',
#  'TheBeatles_ISawHerStandingThere_1964.hum',
#  'EmersonLakeAndPalmer_LuckyMan_1971.harm',
#  'SteveMillerBand_TheJoker_1973.harm',
#  'ElvisPresley_LittleSister_1961.hum',
#  'GoldenEarring_TwilightZone_1983.harm',
#  'TheWho_PinballWizard_1969.hum',
#  'CliffRichard_DaddysHome_1982.harm',
#  'TheRollingStones_TimeIsOnMySide_1964.hum',
#  'TracieSpencer_ThisHouse_1990.harm',
#  'Wednesday_LastKiss_1974.harm',
#  'BobbyDarin_IfIWereACarpenter_1966.harm',
#  'BrendaLee_ComingOnStrong_1966.harm',
#  'CorneliusBrothersAndSisterRose_TreatHerLikeALady_1971.hum',
#  'NancySinatra_TheseBootsAreMadeForWalkin_1966.hum',
#  'KennyRogers_IDontNeedYou_1981.harm',
#  'OtisRedding_IveBeenLovingYouTooLong_1965.harm',
#  'TheBeachBoys_InMyRoom_1963.hum',
#  'RogerMiller_YouCantRollerSkateInABuffaloHerd_1966.hum',
#  'REOSpeedwagon_TimeForMeToFly_1980.hum',
#  'PaulMcCartney_Press_1986.harm',
#  'TheOsmonds_OneBadApple_1971.harm',
#  'SolomonBurke_IfYouNeedMe_1963.harm',
#  'EvelynChampagneKing_ImInLove_1981.harm',
#  'SammyHagar_ICantDrive55_1984.hum',
#  'JohnnyHorton_TheBattleOfNewOrleans_1959.hum',
#  'BobbyBare_DetroitCity_1963.harm',
#  'TheJGeilsBand_OneLastKiss_1978.harm',
#  'BruceChannel_HeyBaby_1962.hum',
#  'TheRitchieFamily_TheBestDiscoInTown_1976.harm',
#  'TheBuckinghams_KindOfADrag_1967.harm',
#  'AnneMurray_CouldIHaveThisDance_1980.hum',
#  'TheRembrandts_Someone_1991.hum',
#  'CyndiLauper_SheBop_1984.harm',
#  'FreddyFender_SecretLove_1975.harm',
#  'TheCure_JustLikeHeaven_1988.harm',
#  'Dion_ThisLittleGirl_1963.harm',
#  'Blondie_IslandOfLostSouls_1982.harm',
#  'JohnnyTillotson_WorriedGuy_1964.harm',
#  'BobSeger_TryinToLiveMyLifeWithoutYou_1981.harm',
#  'Redbone_ComeAndGetYourLove_1974.harm',
#  'Ocean_PutYourHandInTheHand_1971.harm',
#  'TomTHall_TheYearThatClaytonDelaneyDied_1971.harm',
#  'ElvisPresley_MyWay_1978.harm',
#  'Heart_MagicMan_1976.hum',
#  'TheCrystals_TheresNoOther_1961.harm',
#  'MartyRobbins_BigIron_1960.harm',
#  'BillyJoel_JustTheWayYouAre_1978.harm',
#  'JimmySmith_WalkOnTheWildSide_1962.harm',
#  'TheRollingStones_WaitingOnAFriend_1982.harm',
#  'PaperLace_TheNightChicagoDied_1974.harm',
#  'TheAllmanBrothersBand_StraightFromTheHeart_1981.harm',
#  'WilsonPickett_SoulDanceNumberThree_1967.harm',
#  'RobertaFlackAndDonnyHathaway_YouveGotAFriend_1971.harm',
#  'WillieMitchell_2075_1964.harm',
#  'SammyHagar_GiveToLive_1987.harm',
#  'CannedHeat_OnTheRoadAgain_1968.harm',
#  'BonnieRaitt_NickOfTime_1990.harm',
#  'ZZTop_LaGrange_1974.harm',
#  'Boston_Amanda_1986.harm',
#  'TheStringALongs_Wheels_1961.harm',
#  'Cher_JustLikeJesseJames_1989.harm',
#  'BetteMidler_TheRose_1980.harm',
#  'NatalieCole_Unforgettable_1991.harm',
#  'LookingGlass_Brandy_1972.harm',
#  'JerryReed_KoKoJoe_1971.harm',
#  'PsychedelicFurs_PrettyInPink_1986.harm',
#  'OtisRedding_ChainedAndBound_1964.harm',
#  'PetShopBoys_LoveComesQuickly_1986.harm',
#  'TheMusicExplosion_LittleBitOSoul_1967.harm',
#  'LaVernBaker_SeeSeeRider_1963.harm',
#  'PeachesAndHerb_ShakeYourGrooveThing_1978.harm',
#  'BillyJoel_DontAskMeWhy_1980.hum',
#  'ElvisPresley_IReallyDontWantToKnow_1970.harm',
#  'TheEagles_AlreadyGone_1974.hum',
#  'BillySquier_MyKindaLover_1982.harm',
#  'SimonAndGarfunkel_MrsRobinson_1968.hum',
#  'PatBenatar_Heartbreaker_1980.hum',
#  'MarvinGayeAndTammiTerrell_IfICouldBuildMyWholeWorldAroundYou_1967.harm',
#  'CliffRichard_LivingDoll_1959.hum',
#  'Queensryche_SilentLucidity_1991.hum',
#  'RobertaFlack_FeelLikeMakinLove_1974.harm',
#  'Dion_LoversWhoWander_1962.harm',
#  'Switch_TherellNeverBe_1978.harm',
#  'EricCarmen_Sunrise_1976.hum',
#  'AndyGibb_ShadowDancing_1978.hum',
#  'LauraBranigan_Gloria_1982.harm',
#  'ChuckBerry_ReelinAndRockin_1972.hum',
#  'TheBoys_DialMyHeart_1988.harm',
#  'NittyGrittyDirtBand_MakeALittleMagic_1980.harm',
#  'EricClapton_LayDownSally_1978.hum',
#  'TheAnimals_SanFranciscanNights_1967.harm',
#  'TevinCampbell_TellMeWhatYouWantMeToDo_1991.harm',
#  'EddieHolland_Jamie_1962.harm',
#  'BrendaLee_TooManyRivers_1965.harm',
#  'EricClapton_ICantStandIt_1981.harm',
#  'ArethaFranklin_OhMeOhMy_1972.harm',
#  'BobbieGentry_OdeToBillieJoe_1976.harm',
#  'StrayCats_RockThisTown_1982.harm',
#  'GladysKnightAndThePips_LetterFullOfTears_1962.harm',
#  'ElvisPresley_ThereGoesMyEverything_1971.harm',
#  'Commodores_Still_1980.harm',
#  'TalkingHeads_BurningDownTheHouse_1983.harm',
#  'DaveDudley_SixDaysOnTheRoad_1963.harm',
#  'WilsonPickett_InTheMidnightHour_1965.harm',
#  'BillyJoel_Pressure_1983.harm',
#  'Genesis_Misunderstanding_1980.harm',
#  'LesleyGore_CaliforniaNights_1967.hum',
#  'MeatLoaf_ParadiseByTheDashboardLight_1978.harm',
#  'TheRollingStones_NotFadeAway_1964.harm',
#  'MarthaAndTheVandellas_NowhereToRun_1965.harm',
#  'MarieOsmond_PaperRoses_1973.harm',
#  'CheapTrick_DreamPolice_1979.hum',
#  'PaulAnka_LoveMeWarmAndTender_1962.harm',
#  'DinahWashington_Unforgettable_1959.hum',
#  'TheBoxTops_CryLikeABaby_1968.harm',
#  'TheGregKihnBand_Lucky_1985.harm',
#  'RayCharles_LetsGoGetStoned_1966.harm',
#  'TheRollingStones_GoingToAGoGo_1982.harm',
#  'JoniMitchell_BabyIDontCare_1982.hum',
#  'MichaelJackson_ManInTheMirror_1988.harm',
#  'Aerosmith_LastChild_1976.harm',
#  'GlenCampbell_RhinestoneCowboy_1975.harm',
#  'TheEagles_LyinEyes_1975.hum',
#  'ChicoDeBarge_TalkToMe_1987.harm',
#  'DottieWest_ALessonInLeavin_1980.harm',
#  'PurePrairieLeague_Amie_1975.harm',
#  'Kaoma_Lambada_1990.harm',
#  'DavidRuffinAndJimmyRuffin_StandByMe_1970.hum',
#  'BillWithers_LovelyDay_1978.harm',
#  'DarylHallAndJohnOates_SaraSmile_1976.harm',
#  'TheKinks_TillTheEndOfTheDay_1966.hum',
#  'JamesBrown_IDontMind_1961.hum',
#  'Dion_LoveCameToMe_1962.harm',
#  'WaylonJennings_AreYouSureHankDoneItThisWay_1975.harm',
#  'StevieWonder_HigherGround_1973.harm',
#  'GratefulDead_SugarMagnolia_1973.hum',
#  'OtisRedding_TheDockOfTheBay_1968.hum',
#  'PetShopBoys_WhereTheStreetsHaveNoName_1991.harm',
#  'DuranDuran_AllSheWantsIs_1989.harm',
#  'TheBeatles_EightDaysAWeek_1965.hum',
#  'Chicago_MakeMeSmile_1970.harm',
#  'TheJacksons_IWantYouBack_1969.harm',
#  'EltonJohn_PhiladelphiaFreedom_1975.harm',
#  'DavidBowie_ModernLove_1983.harm',
#  'TheTeeSet_MaBelleAmie_1970.harm',
#  'EltonJohn_WhoWearsTheseShoes_1984.hum',
#  'RoyOrbison_CrySoftlyLonelyOne_1967.harm',
#  'DavidBowie_SpaceOddity_1973.harm',
#  'SonnyAndCher_AllIEverNeedIsYou_1971.hum',
#  'CountBasie_GoingToChicagoBlues_1958.harm',
#  'TheJGeilsBand_LookingForALove_1972.harm',
#  'README.md',
#  'NittyGrittyDirtBand_BuyForMeTheRain_1967.hum',
#  'MarvinGayeAndKimWeston_ItTakesTwo_1967.harm',
#  'Metallica_One_1989.hum',
#  'MichaelSembello_Maniac_1983.harm',
#  'AnneMurray_DaydreamBeliever_1980.harm',
#  'Boston_FeelinSatisfied_1979.harm',
#  'ThePolice_DontStandSoCloseToMe_1981.hum',
#  'BobbyWomack_SweetCaroline_1972.harm',
#  'PaulMcCartney_MaybeImAmazed_1977.hum',
#  'JimmyClanton_JustADream_1958.hum',
#  'ATasteOfHoney_Sukiyaki_1981.harm',
#  'BrendaLee_EverybodyLovesMeButYou_1962.harm',
#  'FontellaBass_RescueMe_1965.hum',
#  'GeorgeHarrison_BlowAway_1979.hum',
#  'EricClapton_Promises_1978.harm',
#  'TheByrds_EightMilesHigh_1966.harm',
#  'TheAlanParsonsProject_EyeInTheSky_1982.harm',
#  'SimonAndGarfunkel_ElCondorPasa_1970.hum',
#  'TheEagles_TheLongRun_1980.harm',
#  'DrHook_IfNotYou_1977.harm',
#  'LosLobos_WillTheWolfSurvive_1985.harm',
#  'VillagePeople_InTheNavy_1979.hum',
#  'TheTemptations_AintTooProudToBeg_1966.harm',
#  'Genesis_Abacab_1982.hum',
#  'Chicago_AlongComesAWoman_1985.harm',
#  'Foghat_DrivinWheel_1977.harm',
#  'RitaCoolidge_TheWayYouDoTheThingsYouDo_1978.harm',
#  'RayPrice_ForTheGoodTimes_1970.harm',
#  'Alabama_TakeMeDown_1982.harm',
#  'LittleRiverBand_HappyAnniversary_1978.harm',
#  'JohnDenver_AnniesSong_1974.harm',
#  'TheMoments_WalkRightIn_1963.harm',
#  'TheStapleSingers_IllTakeYouThere_1972.harm',
#  'LouisPrimaAndKeelySmith_ThatOldBlackMagic_1958.harm',
#  'TheBeatles_DoYouWantToKnowASecret_1964.harm',
#  'GlenCampbell_ItsOnlyMakeBelieve_1970.harm',
#  'TheBeatles_ComeTogether_1969.hum',
#  'JuiceNewton_QueenOfHearts_1981.hum',
#  'TheJGeilsBand_FreezeFrame_1982.hum',
#  'Madonna_OhFather_1990.hum',
#  'JethroTull_LivingInThePast_1972.harm',
#  'Cream_SunshineOfYourLove_1968.hum',
#  'JermaineJackson_LetsGetSerious_1980.harm',
#  'LaVernBaker_ICriedATear_1959.hum',
#  'TommyJames_CrystalBluePersuasion_1969.harm',
#  'DarylHallAndJohnOates_Maneater_1983.harm',
#  'The5thDimension_OneLessBellToAnswer_1971.harm',
#  'EttaJames_WouldItMakeAnyDifferenceToYou_1963.harm',
#  'JohnnyCash_TheWaysOfAWomanInLove_1958.hum',
#  'PinkFloyd_AnotherBrickInTheWall_1980.hum',
#  'CyndiLauper_TheGooniesRGoodEnough_1985.hum',
#  'TheCastaways_LiarLiar_1965.harm',
#  'BenEKing_Amor_1961.harm',
#  'EarthWindAndFire_September_1979.hum',
#  'JamesBrown_DownAndOutInNewYorkCity_1973.harm',
#  'IkeAndTinaTurner_ItsGonnaWorkOutFine_1961.harm',
#  'AnnPeebles_ICantStandTheRain_1973.harm',
#  'MinnieRiperton_LovinYou_1975.harm',
#  'RobertJohn_SadEyes_1979.harm',
#  'DepecheMode_WorldInMyEyes_1990.hum',
#  'JuiceNewton_BreakItToMeGently_1982.harm',
#  'Bananarama_Venus_1986.hum',
#  'RayCharles_TheRightTime_1959.harm',
#  'TommyJames_MonyMony_1968.harm',
#  'PetShopBoys_AlwaysOnMyMind_1988.hum',
#  'BarryWhite_YoureTheFirstTheLastMyEverything_1974.harm',
#  'TheYardbirds_ShapesOfThings_1966.harm',
#  'EdwinStarr_War_1970.hum',
#  'BillyIdol_WhiteWedding_1983.hum',
#  'StephanieMills_NeverKnewLoveLikeThisBefore_1980.hum',
#  'CrosbyStillsAndNash_TeachYourChildren_1970.harm',
#  'NickGilder_HotChildInTheCity_1978.harm',
#  'Heart_WhoWillYouRunTo_1987.hum',
#  'Baltimora_TarzanBoy_1986.harm',
#  'MeatLoaf_YouTookTheWordsRightOutOfMyMouth_1978.harm',
#  'TinaTurner_PrivateDancer_1985.harm',
#  'TheCrystals_HesARebel_1962.hum',
#  'SteveWinwood_BackInTheHighLifeAgain_1987.harm',
#  'StevieWonder_DoIDo_1982.harm',
#  'RickDerringer_RockAndRollHoochieKoo_1974.harm',
#  'TheMiracles_ISecondThatEmotion_1968.harm',
#  'Roxette_TheLook_1989.hum',
#  'DrJohn_RightPlaceWrongTime_1973.harm',
#  'CarlCarlton_EverlastingLove_1974.harm',
#  'YvonneElliman_IfICantHaveYou_1978.harm',
#  'TheMiracles_BabyBabyDontCry_1969.harm',
#  'RareEarth_GetReady_1970.harm',
#  'EarthWindAndFire_AfterTheLoveHasGone_1979.harm',
#  'AnitaBaker_CaughtUpInTheRapture_1987.hum',
#  'CyndiLauper_TrueColors_1986.hum',
#  'TheByrds_GoinBack_1967.harm',
#  'ABBA_KnowingMeKnowingYou_1977.harm',
#  'PaulAnka_LetMeGetToKnowYou_1974.harm',
#  'ABBA_HoneyHoney_1974.hum',
#  'Commodores_Easy_1977.harm',
#  'KennyRogers_ThroughTheYears_1981.harm',
#  'TheRascals_PeopleGotToBeFree_1968.hum',
#  'HarryChapin_SundayMorningSunshine_1972.hum',
#  'KennyRogers_SweetMusicMan_1978.harm',
#  'JamesBrown_MyThang_1974.harm',
#  'BobSeger_EvenNow_1983.harm',
#  'GladysKnightAndThePips_BabyDontChangeYourMind_1977.harm',
#  'BayCityRollers_SaturdayNight_1975.harm',
#  'GeorgeHarrison_CrackerboxPalace_1977.hum',
#  'JohnDenver_SeasonsOfTheHeart_1982.hum',
#  'BuckOwens_ThinkOfMe_1966.harm',
#  'FourTops_StandingInTheShadowsOfLove_1967.harm',
#  'VanHalen_WhenItsLove_1988.hum',
#  'TheCowsills_SilverThreadsAndGoldenNeedles_1969.harm',
#  'MelTorme_CominHomeBaby_1962.harm',
#  'PetShopBoys_WhatHaveIDoneToDeserveThis_1988.hum',
#  'BobDylan_GottaServeSomebody_1979.harm',
#  'TheRollingStones_MissYou_1978.hum',
#  'PaulMcCartneyAndWings_MyLove_1973.hum',
#  'JohnDenver_BackHomeAgain_1974.hum',
#  'SonnyAndCher_BabyDontGo_1965.harm',
#  'TheBeatles_AHardDaysNight_1964.hum',
#  'NatKingCole_RamblinRose_1962.harm',
#  'TheYardbirds_HeartFullOfSoul_1965.harm',
#  'DianaRoss_UpsideDown_1980.harm',
#  'StevieWonder_IfYouReallyLoveMe_1971.harm',
#  'BillyPreston_WithYouImBornAgain_1979.harm',
#  'JoniMitchell_BigYellowTaxi_1975.hum',
#  'TheOJays_LoveTrain_1973.harm',
#  'IrmaThomas_WishSomeoneWouldCare_1964.harm',
#  'DollyParton_StartingOverAgain_1980.harm',
#  'ElvisPresley_AskMe_1964.harm',
#  'CandiStaton_YoungHeartsRunFree_1976.harm',
#  'RoxyMusic_DanceAway_1979.harm',
#  'TinaTurner_WhatYouGetIsWhatYouSee_1987.harm',
#  'TheFabulousThunderbirds_TuffEnuff_1986.harm',
#  'Snap_ThePower_1990.harm',
#  'StrayCats_IWontStandInYourWay_1983.harm',
#  'CliffRichard_DevilWoman_1976.harm',
#  'BrendaLee_AsUsual_1964.harm',
#  'Quarterflash_HardenMyHeart_1982.hum',
#  'EngelbertHumperdinck_AfterTheLovin_1977.harm',
#  'EltonJohn_TheBitchIsBack_1974.harm',
#  'ThePointerSisters_HesSoShy_1980.harm',
#  'Chicago_OldDays_1975.harm',
#  'BrendaLee_HeartInHand_1962.harm',
#  'GlenCampbell_Galveston_1969.harm',
#  'KrisKristofferson_LovingHerWasEasier_1971.harm',
#  'TheSupremes_StonedLove_1970.harm',
#  'Heart_CrazyOnYou_1978.hum',
#  'LittleRiverBand_TheOtherGuy_1983.harm',
#  'ToddRundgren_CanWeStillBeFriends_1978.harm',
#  'CyndiLauper_AllThroughTheNight_1984.harm',
#  'The5thDimension_GoWhereYouWannaGo_1967.harm',
#  'GinoVannelli_HurtsToBeInLove_1985.harm',
#  'DrHook_TheMillionaire_1975.harm',
#  'LittleRiverBand_HelpIsOnItsWay_1977.hum',
#  'JohnnyTillotson_TalkBackTremblingLips_1963.harm',
#  'EttaJames_StopTheWedding_1962.harm',
#  'SteveMillerBand_RocknMe_1976.hum',
#  'ThePolice_SpiritsInTheMaterialWorld_1982.harm',
#  'FreddyFender_LivingItDown_1976.harm',
#  'JanAndDean_SidewalkSurfin_1964.hum',
#  'TheRollingStones_WildHorses_1971.hum',
#  'BingCrosby_WhiteChristmas_1962.hum',
#  'TeddyPendergrass_IDontLoveYouAnymore_1977.harm',
#  'PeggyLee_IsThatAllThereIs_1969.harm',
#  'JohnnyHorton_JohnnyReb_1959.hum',
#  'TheTrammps_DiscoInferno_1977.hum',
#  'ShirleyBrown_WomanToWoman_1975.harm',
#  'Cher_IfICouldTurnBackTime_1989.harm',
#  'SonnyAndCher_ACowboysWorkIsNeverDone_1972.harm',
#  'SpandauBallet_True_1983.hum',
#  'Dion_WhereOrWhen_1960.harm',
#  'LittleJoeyAndTheFlips_BongoStomp_1962.harm',
#  'ABBA_TakeAChanceOnMe_1978.harm',
#  'BillyIdol_HotInTheCity_1982.harm',
#  'RitaCoolidge_WereAllAlone_1977.harm',
#  'SimonAndGarfunkel_FakinIt_1967.harm',
#  'UB40_RedRedWine_1984.hum',
#  'SteveWinwood_DontYouKnowWhatTheNightCanDo_1988.harm',
#  'CreedenceClearwaterRevival_BadMoonRising_1969.hum',
#  'TheContours_DoYouLoveMe_1988.harm',
#  'BillySwan_ICanHelp_1974.harm',
#  'Prince_TheArmsOfOrion_1989.harm',
#  'BeastieBoys_BrassMonkey_1987.harm',
#  'GladysKnightAndThePips_IfIWereYourWoman_1971.harm',
#  'CharlieRich_AVerySpecialLoveSong_1974.harm',
#  'KateBush_RunningUpThatHill_1985.harm',
#  'AliceCooper_HeyStoopid_1991.harm',
#  'TheRonettes_BeMyBaby_1963.hum',
#  'SlyAndTheFamilyStone_HotFunInTheSummertime_1969.harm',
#  'StevieB_BecauseILoveYou_1991.hum',
#  'RickSpringfield_DontTalkToStrangers_1982.harm',
#  'GinoVannelli_WildHorses_1987.hum',
#  'JohnDenver_SomeDaysAreDiamonds_1981.harm',
#  'Rush_TheSpiritOfRadio_1980.hum',
#  'RayCharles_CryingTime_1965.harm',
#  'DavidBowie_GoldenYears_1976.harm',
#  'TheHollies_CarrieAnne_1967.hum',
#  'TheChiffons_SweetTalkinGuy_1966.hum',
#  'GeorgeHarrison_AllThoseYearsAgo_1981.harm',
#  'RickJames_SuperFreak_1981.hum',
#  'MichaelJohnson_AlmostLikeBeingInLove_1978.harm',
#  'TheBeatles_IDontWantToSpoilTheParty_1965.harm',
#  'ABBA_Fernando_1976.harm',
#  'WillieNelson_BlueEyesCryingInTheRain_1975.harm',
#  'TheEverlyBrothers_WalkRightBack_1961.hum',
#  'RickJames_GiveItToMeBaby_1981.harm',
#  'TinaTurner_WhatsLoveGotToDoWithIt_1984.hum',
#  'ElvisPresley_OneNight_1959.hum',
#  'TheAmboyDukes_JourneyToTheCenterOfTheMind_1968.harm',
#  'NenehCherry_KissesOnTheWind_1989.harm',
#  'BobSeger_AmericanStorm_1986.harm',
#  'JFrankWilsonAndTheCavaliers_LastKiss_1964.hum',
#  'JamesBrown_BabyYoureRight_1961.harm',
#  'DuranDuran_IsThereSomethingIShouldKnow_1983.hum',
#  'TheEverlyBrothers_EbonyEyes_1961.harm',
#  'PinkFloyd_Money_1973.hum',
#  'CliffRichard_WeDontTalkAnymore_1979.hum',
#  'DrHook_SexyEyes_1980.hum',
#  'LindaRonstadt_WhenWillIBeLoved_1975.hum',
#  'INXS_NeedYouTonight_1988.harm',
#  'JimmyRuffin_IvePassedThisWayBefore_1967.harm',
#  'The5thDimension_NeverMyLove_1971.harm',
#  'ClarenceCarter_TooWeakToFight_1968.harm',
#  'TheBeatles_ShesAWoman_1964.harm',
#  'JoanBaez_ThereButForFortune_1965.harm',
#  'DonGibson_SeaOfHeartbreak_1961.harm',
#  'SmokeyRobinson_Cruisin_1980.harm',
#  'LesleyGore_YouDontOwnMe_1964.harm',
#  'Chicago_AnotherRainyDayInNewYorkCity_1976.harm',
#  'AliceCooper_SchoolsOut_1972.hum',
#  'BrendaLee_SweetNothins_1960.hum',
#  'TheMusicMachine_ThePeopleInMe_1967.harm',
#  'TheRollingStones_DooDooDooDooDoo_1974.harm',
#  'Yaz_Situation_1982.harm',
#  'RonnieMilsap_IWouldntHaveMissedItForTheWorld_1981.harm',
#  'JamesBrown_IGotYou_1965.hum',
#  'NeilSedaka_BreakingUpIsHardToDo_1976.harm',
#  'PaulSimon_50WaysToLeaveYourLover_1976.hum',
#  'Donovan_SunshineSuperman_1966.hum',
#  'JohnnyLee_LookinForLove_1980.harm',
#  'GrahamNash_Chicago_1971.harm',
#  'TheEverlyBrothers_ThatsOldFashioned_1962.hum',
#  'TheBeachBoys_Wendy_1964.harm',
#  'GeorgeHarrison_GotMyMindSetOnYou_1988.hum',
#  'MarvinGaye_IWantYou_1976.harm',
#  'BlueCheer_SummertimeBlues_1968.harm',
#  'RDeanTaylor_IndianaWantsMe_1970.harm',
#  'KennyRogers_Lady_1980.harm',
#  'DollyParton_BabyImBurnin_1979.harm',
#  'GlenCampbell_WichitaLineman_1969.harm',
#  'TheStapleSingers_CityInTheSky_1974.harm',
#  'DrHook_OnlySixteen_1976.harm',
#  'JacksonBrowne_RunningOnEmpty_1978.harm',
#  'TheRobertCrayBand_SmokingGun_1987.hum',
#  'GenePitney_TownWithoutPity_1961.hum',
#  'WilsonPickett_ImInLove_1967.harm',
#  'ElvisPresley_MyWishCameTrue_1959.harm',
#  'AnneMurray_LoveSong_1974.hum',
#  'ColorMeBadd_IAdoreMiAmor_1991.harm',
#  'MilliVanilli_GirlYouKnowItsTrue_1989.harm',
#  'TheMeters_LookKaPyPy_1970.hum',
#  'BillyJoel_AnInnocentMan_1984.harm',
#  'PatBenatar_PromisesInTheDark_1981.harm',
#  'Queen_WeAreTheChampions_1978.hum',
#  'JimmyReed_BabyWhatYouWantMeToDo_1960.hum',
#  'JeffBeck_PeopleGetReady_1985.harm',
#  'Commodores_ThreeTimesALady_1978.harm',
#  'AlGreen_OhMeOhMy_1975.hum',
#  'PeggyLee_Fever_1958.hum',
#  'JohnDenver_RockyMountainHigh_1972.hum',
#  'PhilCollins_TwoHearts_1989.hum',
#  'ClarenceCarter_Patches_1970.harm',
#  'HankSnow_IveBeenEverywhere_1962.hum',
#  'JanisJoplin_KozmicBlues_1969.harm',
#  'JacksonBrowne_HereComeThoseTearsAgain_1977.harm',
#  'MichaelJacksonWithSiedahGarrett_IJustCantStopLovingYou_1987.harm',
#  'TheVentures_Perfidia_1960.harm',
#  'Wham_WakeMeUpBeforeYouGoGo_1984.hum',
#  'Oliver_GoodMorningStarshine_1969.hum',
#  'DarylHallAndJohnOates_KissOnMyList_1981.hum',
#  'TheJGeilsBand_MustOfGotLost_1974.harm',
#  'TinaTurner_TheBest_1989.hum',
#  'JimmyBuffett_ComeMonday_1974.harm',
#  'RodStewart_TwistinTheNightAway_1987.harm',
#  'SimonAndGarfunkel_Cecilia_1970.hum',
#  'PaulSimon_YouCanCallMeAl_1986.harm',
#  'WangChung_DanceHallDays_1984.harm',
#  'WilsonPickett_IFoundATrueLove_1968.harm',
#  'TheMiracles_IDontBlameYouAtAll_1971.hum',
#  'NatalieCole_IveGotLoveOnMyMind_1977.harm',
#  'TheJGeilsBand_JustCantWait_1980.harm',
#  'EdgarWinter_Frankenstein_1973.harm',
#  'JohnDenver_ItAmazesMe_1978.harm',
#  'OakRidgeBoys_Elvira_1981.hum',
#  'CharlieRich_BehindClosedDoors_1973.harm',
#  'EricClapton_WillieAndTheHandJive_1974.hum',
#  'Player_BabyComeBack_1978.harm',
#  'TheBeachBoys_SurfinSafari_1962.harm',
#  'Bread_If_1971.harm',
#  'MilliVanilli_GirlImGonnaMissYou_1989.harm',
#  'Sagittarius_MyWorldFellDown_1967.harm',
#  'YoungMC_BustAMove_1990.harm',
#  'DonnaSummer_LastDance_1978.hum',
#  'DigitalUnderground_TheHumptyDance_1990.harm',
#  'JanAndDean_TheAnaheimAzusaAndCucamongaSewingCircleBookReviewAndTimingAssociation_1964.harm',
#  'ABBA_OnAndOnAndOn_1981.harm',
#  'Bananarama_ATrickOfTheNight_1987.harm',
#  'RockAndHyde_DirtyWater_1987.harm',
#  'ElvisPresley_MyBoy_1975.harm',
#  'BobSeger_OldTimeRockAndRoll_1979.harm',
#  'TheEverlyBrothers_BirdDog_1958.hum',
#  'BBKing_TheThrillIsGone_1970.harm',
#  'RoyHead_TreatHerRight_1965.harm',
#  'ElvisPresley_Judy_1967.harm',
#  'PatBenatar_FireAndIce_1981.harm',
#  'TheGregKihnBand_HappyMan_1982.harm',
#  'BachmanTurnerOverdrive_Heartaches_1979.harm',
#  'BoDiddley_YouCantJudgeABookByTheCover_1962.harm',
#  'BizMarkie_JustAFriend_1990.hum',
#  'TheEagles_BestOfMyLove_1975.harm',
#  'GaryUSBonds_QuarterToThree_1961.harm',
#  'Sting_AllThisTime_1991.harm',
#  'Kiss_RocketRide_1978.hum',
#  'Badfinger_MaybeTomorrow_1969.harm',
#  'TheWho_HappyJack_1967.hum',
#  'ThePointerSisters_Jump_1984.harm',
#  'BerthaTillman_OhMyAngel_1962.harm',
#  'LittleRiverBand_Reminiscing_1978.hum',
#  'Santana_EvilWays_1970.hum',
#  'JanAndDean_TheLittleOldLady_1964.hum',
#  'LynyrdSkynyrd_SweetHomeAlabama_1974.hum',
#  'EricClapton_ForeverMan_1985.harm',
#  'SlyAndTheFamilyStone_IWantToTakeYouHigher_1969.harm',
#  'EttaJames_FoolThatIAm_1961.harm',
#  'CreedenceClearwaterRevival_IPutASpellOnYou_1968.hum',
#  'JohnnyTillotson_IRiseIFall_1964.harm',
#  'RitaCoolidge_HigherAndHigher_1977.harm',
#  'BBKing_HowBlueCanYouGet_1964.harm',
#  'JimmyJones_HandyMan_1960.harm',
#  'KennyRogers_YouDecoratedMyLife_1980.harm',
#  'LedZeppelin_TrampledUnderFoot_1975.harm',
#  'TheCowsills_Hair_1969.harm',
#  'Commodores_Nightshift_1985.hum',
#  'TheFalcons_IFoundALove_1962.harm',
#  'BoyzIIMen_Motownphilly_1991.harm',
#  'GlenCampbell_Sunflower_1977.harm',
#  'TheRollingStones_TumblingDice_1972.harm',
#  'MelbaMontgomery_NoCharge_1974.harm',
#  'GeorgeBenson_Breezin_1976.harm',
#  'StevieWonder_ThatGirl_1982.harm',
#  'TheJacksons_DancingMachine_1974.harm',
#  'JamesBrown_Think_1973.harm',
#  'CheapTrick_StopThisGame_1980.harm',
#  'FiveManElectricalBand_AbsolutelyRight_1971.harm',
#  'LouisArmstrong_HelloDolly_1964.hum',
#  'CrosbyStillsAndNash_SouthernCross_1982.harm',
#  'BrendaLee_LosingYou_1963.harm',
#  'DarylHallAndJohnOates_RichGirl_1977.harm',
#  'BuckOwens_IveGotATigerByTheTail_1965.harm',
#  'RitaCoolidge_Fever_1973.harm',
#  'TheDoobieBrothers_EchoesOfLove_1977.harm',
#  'TheMiracles_MightyGoodLovin_1961.harm',
#  'ElvisPresley_ForOlTimesSake_1973.harm',
#  'BillySquier_TheStroke_1981.hum',
#  'BrendaLee_DumDum_1961.harm',
#  'BarbaraLewis_HelloStranger_1963.harm',
#  'TalkingHeads_AndSheWas_1985.harm']

# %%
harm_files = [file for file in glob.glob('*.harm')]
harm_files
# Out:
# ['MichaelJackson_HumanNature_1983.harm',
#  'TheBabys_EveryTimeIThinkOfYou_1979.harm',
#  'GladysKnightAndThePips_BestThingThatEverHappenedToMe_1974.harm',
#  'FloydCramer_LastDate_1960.harm',
#  'CrosbyStillsAndNash_SuiteJudyBlueEyes_1969.harm',
#  'TheRollingStones_ItsOnlyRockNRoll_1974.harm',
#  'FatsDomino_IWantToWalkYouHome_1959.harm',
#  'BrotherJackMcDuff_ThemeFromElectricSurfboard_1969.harm',
#  'PatBenatar_LittleTooLate_1983.harm',
#  'CheapTrick_IWantYouToWantMe_1979.harm',
#  'Madonna_LiveToTell_1986.harm',
#  'RickSpringfield_JessiesGirl_1981.harm',
#  'AlanODay_UndercoverAngel_1977.harm',
#  'CheapTrick_Surrender_1978.harm',
#  'DinahWashington_WhereAreYou_1962.harm',
#  'Shannon_LetTheMusicPlay_1984.harm',
#  'WilsonPickett_DontKnockMyLovePt1_1971.harm',
#  'ChrisKenner_LandOf1000Dances_1963.harm',
#  'JohnnyTillotson_ItKeepsRightOnAHurtin_1962.harm',
#  'CoreyHart_InYourSoul_1988.harm',
#  'BarbraStreisand_FunnyGirl_1964.harm',
#  'DrHook_YearsFromNow_1980.harm',
#  'BillyIdol_FleshForFantasy_1984.harm',
#  'Dion_RunaroundSue_1961.harm',
#  'Chicago_AliveAgain_1978.harm',
#  'TheBeachBoys_SailOnSailor_1975.harm',
#  'JoeCocker_WithALittleHelpFromMyFriends_1968.harm',
#  'RodBernard_ThisShouldGoOnForever_1959.harm',
#  'Dion_RubyBaby_1963.harm',
#  'BrownsvilleStation_SmokinInTheBoysRoom_1973.harm',
#  'NatKingCole_ThoseLazyHazyCrazyDaysOfSummer_1963.harm',
#  'Focus_HocusPocus_1973.harm',
#  'JohnnyTillotson_OutOfMyMind_1963.harm',
#  'TheYoungbloods_GetTogether_1969.harm',
#  'DonnaFargo_Superman_1973.harm',
#  'IsaacHayes_DoYourThing_1972.harm',
#  'JimiHendrix_Freedom_1971.harm',
#  'RayCharles_EleanorRigby_1968.harm',
#  'BonniePointer_HeavenMustHaveSentYou_1979.harm',
#  'TheHollies_LongDarkRoad_1972.harm',
#  'BillWithers_AintNoSunshine_1971.harm',
#  'EltonJohn_Levon_1971.harm',
#  'TheIsleyBrothers_ItsYourThing_1969.harm',
#  'AaronNeville_TellItLikeItIs_1966.harm',
#  'JackieWilson_BabyWorkout_1963.harm',
#  'PaulMcCartney_WithALittleLuck_1978.harm',
#  'TheDrifters_OnBroadway_1963.harm',
#  'BrendaLee_AllAloneAmI_1962.harm',
#  'BobSeger_AgainstTheWind_1980.harm',
#  'KennyRogers_ScarletFever_1983.harm',
#  'BillySquier_DontSayYouLoveMe_1989.harm',
#  'BobbiMartin_ILoveYouSo_1965.harm',
#  'BarbraStreisand_People_1964.harm',
#  'ToddRundgren_ADreamGoesOnForever_1974.harm',
#  'Sting_IfYouLoveSomebodySetThemFree_1985.harm',
#  'GeorgeHarrison_ThisSong_1977.harm',
#  'DuranDuran_IDontWantYourLove_1989.harm',
#  'FreddieJackson_HaveYouEverLovedSomebody_1987.harm',
#  'CannedHeat_LetsWorkTogether_1970.harm',
#  'GinoVannelli_BlackCars_1985.harm',
#  'ThePowerStation_SomeLikeItHot_1985.harm',
#  'LittleRiverBand_WeTwo_1983.harm',
#  'Bread_SweetSurrender_1972.harm',
#  'JamesTaylor_CountryRoad_1971.harm',
#  'RodStewart_MaggieMay_1971.harm',
#  'LittleAnthonyAndTheImperials_OutOfSightOutOfMind_1969.harm',
#  'CultureClub_IllTumble4Ya_1983.harm',
#  'BobSeger_RockAndRollNeverForgets_1977.harm',
#  'RobertPalmer_AddictedToLove_1986.harm',
#  'ThelmaHouston_DontLeaveMeThisWay_1977.harm',
#  'BadCompany_RockNRollFantasy_1979.harm',
#  'IsaacHayes_TheLookOfLove_1971.harm',
#  'RayParkerJr_Ghostbusters_1984.harm',
#  'SwinginMedallions_DoubleShot_1966.harm',
#  'Dion_AbrahamMartinAndJohn_1968.harm',
#  'TheRollingStones_Dandelion_1967.harm',
#  'ChuckBerry_SweetLittleRockAndRoll_1958.harm',
#  'MichaelJackson_WannaBeStartinSomethin_1983.harm',
#  'JesusJones_RightHereRightNow_1991.harm',
#  'CrosbyStillsAndNash_GotItMade_1989.harm',
#  'MaxFrostAndTheTroopers_ShapeOfThingsToCome_1968.harm',
#  'HueyLewis_IWantANewDrug_1984.harm',
#  'DavidCrosbyAndGrahamNash_CarryMe_1975.harm',
#  'BobbyWomack_ThatsTheWayIFeelAboutCha_1971.harm',
#  'TheBeachBoys_BluebirdsOverTheMountain_1969.harm',
#  'RoyDrusky_ThreeHeartsInATangle_1961.harm',
#  'SantoAndJohnny_SleepWalk_1959.harm',
#  'Dion_BornToCry_1962.harm',
#  'TheEverlyBrothers_OnTheWingsOfANightingale_1984.harm',
#  'TheDramatics_HeyYouGetOffMyMountain_1973.harm',
#  'GordonLightfoot_Beautiful_1972.harm',
#  'AnitaBaker_GivingYouTheBestThatIGot_1989.harm',
#  'WaylonJennings_ThemeFromTheDukesOfHazzard_1980.harm',
#  'RandyVanwarmer_JustWhenINeededYouMost_1979.harm',
#  'TheBeachBoys_StillCruisin_1989.harm',
#  'TheSupremes_FloyJoy_1972.harm',
#  'FlattAndScruggs_FoggyMountainBreakdown_1968.harm',
#  'TheSopwithCamel_HelloHello_1967.harm',
#  'TenYearsAfter_IdLoveToChangeTheWorld_1971.harm',
#  'ArethaFranklin_ChainOfFools_1967.harm',
#  'JimmyCliff_WonderfulWorldBeautifulPeople_1969.harm',
#  'RunDMC_WalkThisWay_1986.harm',
#  'JohnnyTillotson_JimmysGirl_1961.harm',
#  'Heart_TheresTheGirl_1988.harm',
#  'TheFireballs_SugarShack_1963.harm',
#  'JeffersonStarship_CountOnMe_1978.harm',
#  'ThePolice_EveryLittleThingSheDoesIsMagic_1981.harm',
#  'DeanMartin_IWill_1965.harm',
#  'WildCherry_PlayThatFunkyMusic_1976.harm',
#  'JacksonBrowne_RedneckFriend_1973.harm',
#  'PatrickHernandez_BornToBeAlive_1979.harm',
#  'ArthurConley_SweetSoulMusic_1967.harm',
#  'IronButterfly_InAGaddaDaVida_1968.harm',
#  'PatBenatar_LoveIsABattlefield_1983.harm',
#  'EarthWindAndFire_Getaway_1976.harm',
#  'IkeAndTinaTurner_IWantToTakeYouHigher_1970.harm',
#  'DeLaSoul_MeMyselfAndI_1989.harm',
#  'RobBase_ItTakesTwo_1988.harm',
#  'GeneralPublic_Tenderness_1984.harm',
#  'TanyaTucker_HeresSomeLove_1976.harm',
#  'The5thDimension_IDidntGetToSleepAtAll_1972.harm',
#  'Genesis_TonightTonightTonight_1987.harm',
#  'TomTHall_ILove_1973.harm',
#  'UB40_TheWayYouDoTheThingsYouDo_1990.harm',
#  'RobertJohn_LonelyEyes_1980.harm',
#  'ElvisPresley_IfICanDream_1968.harm',
#  'TheRighteousBrothers_SoulAndInspiration_1966.harm',
#  'CliffRichard_Carrie_1980.harm',
#  'TracyChapman_BabyCanIHoldYou_1989.harm',
#  'HiFive_ILikeTheWay_1991.harm',
#  'KennyRogers_Lucille_1977.harm',
#  'ElvisPresley_SheThinksIStillCare_1977.harm',
#  'MarcCohn_WalkingInMemphis_1991.harm',
#  'BillyIdol_CatchMyFall_1985.harm',
#  'DeanMartin_EverybodyLovesSomebody_1964.harm',
#  'MartyRobbins_IWalkAlone_1968.harm',
#  'DoubleExposure_TenPercent_1976.harm',
#  'GrandFunkRailroad_WalkLikeAMan_1973.harm',
#  'BobSeger_NightMoves_1977.harm',
#  'DrHook_WalkRightIn_1977.harm',
#  'Poison_UnskinnyBop_1990.harm',
#  'CyndiLauper_IDroveAllNight_1989.harm',
#  'JacksonBrowne_Boulevard_1980.harm',
#  'TheRollingStones_HaveYouSeenYourMotherBabyStandingInTheShadow_1966.harm',
#  'ArethaFranklin_INeverLovedAMan_1967.harm',
#  'UrbanDanceSquad_DeeperShadeOfSoul_1991.harm',
#  'Debarge_TimeWillReveal_1984.harm',
#  'BJThomas_HookedOnAFeeling_1968.harm',
#  'TheBand_LifeIsACarnival_1971.harm',
#  'ElvisPresley_HisLatestFlame_1961.harm',
#  'TheTemptations_IWishItWouldRain_1968.harm',
#  'EddieRabbitt_ILoveARainyNight_1981.harm',
#  'CharlieRich_LonelyWeekends_1960.harm',
#  'MaryMacGregor_TornBetweenTwoLovers_1976.harm',
#  'EricCarmen_HungryEyes_1988.harm',
#  'Firehouse_DontTreatMeBad_1991.harm',
#  'Genesis_InvisibleTouch_1986.harm',
#  'EmersonLakeAndPalmer_LuckyMan_1971.harm',
#  'SteveMillerBand_TheJoker_1973.harm',
#  'GoldenEarring_TwilightZone_1983.harm',
#  'CliffRichard_DaddysHome_1982.harm',
#  'TracieSpencer_ThisHouse_1990.harm',
#  'Wednesday_LastKiss_1974.harm',
#  'BobbyDarin_IfIWereACarpenter_1966.harm',
#  'BrendaLee_ComingOnStrong_1966.harm',
#  'KennyRogers_IDontNeedYou_1981.harm',
#  'OtisRedding_IveBeenLovingYouTooLong_1965.harm',
#  'PaulMcCartney_Press_1986.harm',
#  'TheOsmonds_OneBadApple_1971.harm',
#  'SolomonBurke_IfYouNeedMe_1963.harm',
#  'EvelynChampagneKing_ImInLove_1981.harm',
#  'BobbyBare_DetroitCity_1963.harm',
#  'TheJGeilsBand_OneLastKiss_1978.harm',
#  'TheRitchieFamily_TheBestDiscoInTown_1976.harm',
#  'TheBuckinghams_KindOfADrag_1967.harm',
#  'CyndiLauper_SheBop_1984.harm',
#  'FreddyFender_SecretLove_1975.harm',
#  'TheCure_JustLikeHeaven_1988.harm',
#  'Dion_ThisLittleGirl_1963.harm',
#  'Blondie_IslandOfLostSouls_1982.harm',
#  'JohnnyTillotson_WorriedGuy_1964.harm',
#  'BobSeger_TryinToLiveMyLifeWithoutYou_1981.harm',
#  'Redbone_ComeAndGetYourLove_1974.harm',
#  'Ocean_PutYourHandInTheHand_1971.harm',
#  'TomTHall_TheYearThatClaytonDelaneyDied_1971.harm',
#  'ElvisPresley_MyWay_1978.harm',
#  'TheCrystals_TheresNoOther_1961.harm',
#  'MartyRobbins_BigIron_1960.harm',
#  'BillyJoel_JustTheWayYouAre_1978.harm',
#  'JimmySmith_WalkOnTheWildSide_1962.harm',
#  'TheRollingStones_WaitingOnAFriend_1982.harm',
#  'PaperLace_TheNightChicagoDied_1974.harm',
#  'TheAllmanBrothersBand_StraightFromTheHeart_1981.harm',
#  'WilsonPickett_SoulDanceNumberThree_1967.harm',
#  'RobertaFlackAndDonnyHathaway_YouveGotAFriend_1971.harm',
#  'WillieMitchell_2075_1964.harm',
#  'SammyHagar_GiveToLive_1987.harm',
#  'CannedHeat_OnTheRoadAgain_1968.harm',
#  'BonnieRaitt_NickOfTime_1990.harm',
#  'ZZTop_LaGrange_1974.harm',
#  'Boston_Amanda_1986.harm',
#  'TheStringALongs_Wheels_1961.harm',
#  'Cher_JustLikeJesseJames_1989.harm',
#  'BetteMidler_TheRose_1980.harm',
#  'NatalieCole_Unforgettable_1991.harm',
#  'LookingGlass_Brandy_1972.harm',
#  'JerryReed_KoKoJoe_1971.harm',
#  'PsychedelicFurs_PrettyInPink_1986.harm',
#  'OtisRedding_ChainedAndBound_1964.harm',
#  'PetShopBoys_LoveComesQuickly_1986.harm',
#  'TheMusicExplosion_LittleBitOSoul_1967.harm',
#  'LaVernBaker_SeeSeeRider_1963.harm',
#  'PeachesAndHerb_ShakeYourGrooveThing_1978.harm',
#  'ElvisPresley_IReallyDontWantToKnow_1970.harm',
#  'BillySquier_MyKindaLover_1982.harm',
#  'MarvinGayeAndTammiTerrell_IfICouldBuildMyWholeWorldAroundYou_1967.harm',
#  'RobertaFlack_FeelLikeMakinLove_1974.harm',
#  'Dion_LoversWhoWander_1962.harm',
#  'Switch_TherellNeverBe_1978.harm',
#  'LauraBranigan_Gloria_1982.harm',
#  'TheBoys_DialMyHeart_1988.harm',
#  'NittyGrittyDirtBand_MakeALittleMagic_1980.harm',
#  'TheAnimals_SanFranciscanNights_1967.harm',
#  'TevinCampbell_TellMeWhatYouWantMeToDo_1991.harm',
#  'EddieHolland_Jamie_1962.harm',
#  'BrendaLee_TooManyRivers_1965.harm',
#  'EricClapton_ICantStandIt_1981.harm',
#  'ArethaFranklin_OhMeOhMy_1972.harm',
#  'BobbieGentry_OdeToBillieJoe_1976.harm',
#  'StrayCats_RockThisTown_1982.harm',
#  'GladysKnightAndThePips_LetterFullOfTears_1962.harm',
#  'ElvisPresley_ThereGoesMyEverything_1971.harm',
#  'Commodores_Still_1980.harm',
#  'TalkingHeads_BurningDownTheHouse_1983.harm',
#  'DaveDudley_SixDaysOnTheRoad_1963.harm',
#  'WilsonPickett_InTheMidnightHour_1965.harm',
#  'BillyJoel_Pressure_1983.harm',
#  'Genesis_Misunderstanding_1980.harm',
#  'MeatLoaf_ParadiseByTheDashboardLight_1978.harm',
#  'TheRollingStones_NotFadeAway_1964.harm',
#  'MarthaAndTheVandellas_NowhereToRun_1965.harm',
#  'MarieOsmond_PaperRoses_1973.harm',
#  'PaulAnka_LoveMeWarmAndTender_1962.harm',
#  'TheBoxTops_CryLikeABaby_1968.harm',
#  'TheGregKihnBand_Lucky_1985.harm',
#  'RayCharles_LetsGoGetStoned_1966.harm',
#  'TheRollingStones_GoingToAGoGo_1982.harm',
#  'MichaelJackson_ManInTheMirror_1988.harm',
#  'Aerosmith_LastChild_1976.harm',
#  'GlenCampbell_RhinestoneCowboy_1975.harm',
#  'ChicoDeBarge_TalkToMe_1987.harm',
#  'DottieWest_ALessonInLeavin_1980.harm',
#  'PurePrairieLeague_Amie_1975.harm',
#  'Kaoma_Lambada_1990.harm',
#  'BillWithers_LovelyDay_1978.harm',
#  'DarylHallAndJohnOates_SaraSmile_1976.harm',
#  'Dion_LoveCameToMe_1962.harm',
#  'WaylonJennings_AreYouSureHankDoneItThisWay_1975.harm',
#  'StevieWonder_HigherGround_1973.harm',
#  'PetShopBoys_WhereTheStreetsHaveNoName_1991.harm',
#  'DuranDuran_AllSheWantsIs_1989.harm',
#  'Chicago_MakeMeSmile_1970.harm',
#  'EltonJohn_PhiladelphiaFreedom_1975.harm',
#  'DavidBowie_ModernLove_1983.harm',
#  'TheTeeSet_MaBelleAmie_1970.harm',
#  'RoyOrbison_CrySoftlyLonelyOne_1967.harm',
#  'DavidBowie_SpaceOddity_1973.harm',
#  'CountBasie_GoingToChicagoBlues_1958.harm',
#  'TheJGeilsBand_LookingForALove_1972.harm',
#  'MarvinGayeAndKimWeston_ItTakesTwo_1967.harm',
#  'MichaelSembello_Maniac_1983.harm',
#  'AnneMurray_DaydreamBeliever_1980.harm',
#  'Boston_FeelinSatisfied_1979.harm',
#  'BobbyWomack_SweetCaroline_1972.harm',
#  'ATasteOfHoney_Sukiyaki_1981.harm',
#  'BrendaLee_EverybodyLovesMeButYou_1962.harm',
#  'EricClapton_Promises_1978.harm',
#  'TheByrds_EightMilesHigh_1966.harm',
#  'TheAlanParsonsProject_EyeInTheSky_1982.harm',
#  'TheEagles_TheLongRun_1980.harm',
#  'DrHook_IfNotYou_1977.harm',
#  'LosLobos_WillTheWolfSurvive_1985.harm',
#  'TheTemptations_AintTooProudToBeg_1966.harm',
#  'Chicago_AlongComesAWoman_1985.harm',
#  'Foghat_DrivinWheel_1977.harm',
#  'RitaCoolidge_TheWayYouDoTheThingsYouDo_1978.harm',
#  'RayPrice_ForTheGoodTimes_1970.harm',
#  'Alabama_TakeMeDown_1982.harm',
#  'LittleRiverBand_HappyAnniversary_1978.harm',
#  'JohnDenver_AnniesSong_1974.harm',
#  'TheMoments_WalkRightIn_1963.harm',
#  'TheStapleSingers_IllTakeYouThere_1972.harm',
#  'LouisPrimaAndKeelySmith_ThatOldBlackMagic_1958.harm',
#  'TheBeatles_DoYouWantToKnowASecret_1964.harm',
#  'GlenCampbell_ItsOnlyMakeBelieve_1970.harm',
#  'JethroTull_LivingInThePast_1972.harm',
#  'JermaineJackson_LetsGetSerious_1980.harm',
#  'TommyJames_CrystalBluePersuasion_1969.harm',
#  'DarylHallAndJohnOates_Maneater_1983.harm',
#  'The5thDimension_OneLessBellToAnswer_1971.harm',
#  'EttaJames_WouldItMakeAnyDifferenceToYou_1963.harm',
#  'TheCastaways_LiarLiar_1965.harm',
#  'BenEKing_Amor_1961.harm',
#  'JamesBrown_DownAndOutInNewYorkCity_1973.harm',
#  'IkeAndTinaTurner_ItsGonnaWorkOutFine_1961.harm',
#  'AnnPeebles_ICantStandTheRain_1973.harm',
#  'MinnieRiperton_LovinYou_1975.harm',
#  'RobertJohn_SadEyes_1979.harm',
#  'JuiceNewton_BreakItToMeGently_1982.harm',
#  'RayCharles_TheRightTime_1959.harm',
#  'TommyJames_MonyMony_1968.harm',
#  'BarryWhite_YoureTheFirstTheLastMyEverything_1974.harm',
#  'TheYardbirds_ShapesOfThings_1966.harm',
#  'CrosbyStillsAndNash_TeachYourChildren_1970.harm',
#  'NickGilder_HotChildInTheCity_1978.harm',
#  'Baltimora_TarzanBoy_1986.harm',
#  'MeatLoaf_YouTookTheWordsRightOutOfMyMouth_1978.harm',
#  'TinaTurner_PrivateDancer_1985.harm',
#  'SteveWinwood_BackInTheHighLifeAgain_1987.harm',
#  'StevieWonder_DoIDo_1982.harm',
#  'RickDerringer_RockAndRollHoochieKoo_1974.harm',
#  'TheMiracles_ISecondThatEmotion_1968.harm',
#  'DrJohn_RightPlaceWrongTime_1973.harm',
#  'CarlCarlton_EverlastingLove_1974.harm',
#  'YvonneElliman_IfICantHaveYou_1978.harm',
#  'TheMiracles_BabyBabyDontCry_1969.harm',
#  'RareEarth_GetReady_1970.harm',
#  'EarthWindAndFire_AfterTheLoveHasGone_1979.harm',
#  'TheByrds_GoinBack_1967.harm',
#  'ABBA_KnowingMeKnowingYou_1977.harm',
#  'PaulAnka_LetMeGetToKnowYou_1974.harm',
#  'Commodores_Easy_1977.harm',
#  'KennyRogers_ThroughTheYears_1981.harm',
#  'KennyRogers_SweetMusicMan_1978.harm',
#  'JamesBrown_MyThang_1974.harm',
#  'BobSeger_EvenNow_1983.harm',
#  'GladysKnightAndThePips_BabyDontChangeYourMind_1977.harm',
#  'BayCityRollers_SaturdayNight_1975.harm',
#  'BuckOwens_ThinkOfMe_1966.harm',
#  'FourTops_StandingInTheShadowsOfLove_1967.harm',
#  'TheCowsills_SilverThreadsAndGoldenNeedles_1969.harm',
#  'MelTorme_CominHomeBaby_1962.harm',
#  'BobDylan_GottaServeSomebody_1979.harm',
#  'SonnyAndCher_BabyDontGo_1965.harm',
#  'NatKingCole_RamblinRose_1962.harm',
#  'TheYardbirds_HeartFullOfSoul_1965.harm',
#  'DianaRoss_UpsideDown_1980.harm',
#  'StevieWonder_IfYouReallyLoveMe_1971.harm',
#  'BillyPreston_WithYouImBornAgain_1979.harm',
#  'TheOJays_LoveTrain_1973.harm',
#  'IrmaThomas_WishSomeoneWouldCare_1964.harm',
#  'DollyParton_StartingOverAgain_1980.harm',
#  'ElvisPresley_AskMe_1964.harm',
#  'CandiStaton_YoungHeartsRunFree_1976.harm',
#  'RoxyMusic_DanceAway_1979.harm',
#  'TinaTurner_WhatYouGetIsWhatYouSee_1987.harm',
#  'TheFabulousThunderbirds_TuffEnuff_1986.harm',
#  'Snap_ThePower_1990.harm',
#  'StrayCats_IWontStandInYourWay_1983.harm',
#  'CliffRichard_DevilWoman_1976.harm',
#  'BrendaLee_AsUsual_1964.harm',
#  'EngelbertHumperdinck_AfterTheLovin_1977.harm',
#  'EltonJohn_TheBitchIsBack_1974.harm',
#  'ThePointerSisters_HesSoShy_1980.harm',
#  'Chicago_OldDays_1975.harm',
#  'BrendaLee_HeartInHand_1962.harm',
#  'GlenCampbell_Galveston_1969.harm',
#  'KrisKristofferson_LovingHerWasEasier_1971.harm',
#  'TheSupremes_StonedLove_1970.harm',
#  'LittleRiverBand_TheOtherGuy_1983.harm',
#  'ToddRundgren_CanWeStillBeFriends_1978.harm',
#  'CyndiLauper_AllThroughTheNight_1984.harm',
#  'The5thDimension_GoWhereYouWannaGo_1967.harm',
#  'GinoVannelli_HurtsToBeInLove_1985.harm',
#  'DrHook_TheMillionaire_1975.harm',
#  'JohnnyTillotson_TalkBackTremblingLips_1963.harm',
#  'EttaJames_StopTheWedding_1962.harm',
#  'ThePolice_SpiritsInTheMaterialWorld_1982.harm',
#  'FreddyFender_LivingItDown_1976.harm',
#  'TeddyPendergrass_IDontLoveYouAnymore_1977.harm',
#  'PeggyLee_IsThatAllThereIs_1969.harm',
#  'ShirleyBrown_WomanToWoman_1975.harm',
#  'Cher_IfICouldTurnBackTime_1989.harm',
#  'SonnyAndCher_ACowboysWorkIsNeverDone_1972.harm',
#  'Dion_WhereOrWhen_1960.harm',
#  'LittleJoeyAndTheFlips_BongoStomp_1962.harm',
#  'ABBA_TakeAChanceOnMe_1978.harm',
#  'BillyIdol_HotInTheCity_1982.harm',
#  'RitaCoolidge_WereAllAlone_1977.harm',
#  'SimonAndGarfunkel_FakinIt_1967.harm',
#  'SteveWinwood_DontYouKnowWhatTheNightCanDo_1988.harm',
#  'TheContours_DoYouLoveMe_1988.harm',
#  'BillySwan_ICanHelp_1974.harm',
#  'Prince_TheArmsOfOrion_1989.harm',
#  'BeastieBoys_BrassMonkey_1987.harm',
#  'GladysKnightAndThePips_IfIWereYourWoman_1971.harm',
#  'CharlieRich_AVerySpecialLoveSong_1974.harm',
#  'TheJackson5_IWantYouBack_1969.harm',
#  'KateBush_RunningUpThatHill_1985.harm',
#  'AliceCooper_HeyStoopid_1991.harm',
#  'SlyAndTheFamilyStone_HotFunInTheSummertime_1969.harm',
#  'RickSpringfield_DontTalkToStrangers_1982.harm',
#  'JohnDenver_SomeDaysAreDiamonds_1981.harm',
#  'RayCharles_CryingTime_1965.harm',
#  'DavidBowie_GoldenYears_1976.harm',
#  'GeorgeHarrison_AllThoseYearsAgo_1981.harm',
#  'MichaelJohnson_AlmostLikeBeingInLove_1978.harm',
#  'TheBeatles_IDontWantToSpoilTheParty_1965.harm',
#  'ABBA_Fernando_1976.harm',
#  'WillieNelson_BlueEyesCryingInTheRain_1975.harm',
#  'RickJames_GiveItToMeBaby_1981.harm',
#  'TheAmboyDukes_JourneyToTheCenterOfTheMind_1968.harm',
#  'NenehCherry_KissesOnTheWind_1989.harm',
#  'BobSeger_AmericanStorm_1986.harm',
#  'JamesBrown_BabyYoureRight_1961.harm',
#  'TheEverlyBrothers_EbonyEyes_1961.harm',
#  'INXS_NeedYouTonight_1988.harm',
#  'JimmyRuffin_IvePassedThisWayBefore_1967.harm',
#  'The5thDimension_NeverMyLove_1971.harm',
#  'ClarenceCarter_TooWeakToFight_1968.harm',
#  'TheBeatles_ShesAWoman_1964.harm',
#  'JoanBaez_ThereButForFortune_1965.harm',
#  'DonGibson_SeaOfHeartbreak_1961.harm',
#  'SmokeyRobinson_Cruisin_1980.harm',
#  'LesleyGore_YouDontOwnMe_1964.harm',
#  'Chicago_AnotherRainyDayInNewYorkCity_1976.harm',
#  'TheMusicMachine_ThePeopleInMe_1967.harm',
#  'TheRollingStones_DooDooDooDooDoo_1974.harm',
#  'Yaz_Situation_1982.harm',
#  'RonnieMilsap_IWouldntHaveMissedItForTheWorld_1981.harm',
#  'NeilSedaka_BreakingUpIsHardToDo_1976.harm',
#  'JohnnyLee_LookinForLove_1980.harm',
#  'GrahamNash_Chicago_1971.harm',
#  'TheBeachBoys_Wendy_1964.harm',
#  'MarvinGaye_IWantYou_1976.harm',
#  'BlueCheer_SummertimeBlues_1968.harm',
#  'RDeanTaylor_IndianaWantsMe_1970.harm',
#  'KennyRogers_Lady_1980.harm',
#  'DollyParton_BabyImBurnin_1979.harm',
#  'GlenCampbell_WichitaLineman_1969.harm',
#  'TheStapleSingers_CityInTheSky_1974.harm',
#  'DrHook_OnlySixteen_1976.harm',
#  'JacksonBrowne_RunningOnEmpty_1978.harm',
#  'WilsonPickett_ImInLove_1967.harm',
#  'ElvisPresley_MyWishCameTrue_1959.harm',
#  'ColorMeBadd_IAdoreMiAmor_1991.harm',
#  'MilliVanilli_GirlYouKnowItsTrue_1989.harm',
#  'BillyJoel_AnInnocentMan_1984.harm',
#  'PatBenatar_PromisesInTheDark_1981.harm',
#  'JeffBeck_PeopleGetReady_1985.harm',
#  'Commodores_ThreeTimesALady_1978.harm',
#  'ClarenceCarter_Patches_1970.harm',
#  'JanisJoplin_KozmicBlues_1969.harm',
#  'JacksonBrowne_HereComeThoseTearsAgain_1977.harm',
#  'MichaelJacksonWithSiedahGarrett_IJustCantStopLovingYou_1987.harm',
#  'TheVentures_Perfidia_1960.harm',
#  'TheJGeilsBand_MustOfGotLost_1974.harm',
#  'JimmyBuffett_ComeMonday_1974.harm',
#  'RodStewart_TwistinTheNightAway_1987.harm',
#  'PaulSimon_YouCanCallMeAl_1986.harm',
#  'WangChung_DanceHallDays_1984.harm',
#  'WilsonPickett_IFoundATrueLove_1968.harm',
#  'NatalieCole_IveGotLoveOnMyMind_1977.harm',
#  'TheJGeilsBand_JustCantWait_1980.harm',
#  'EdgarWinter_Frankenstein_1973.harm',
#  'JohnDenver_ItAmazesMe_1978.harm',
#  'CharlieRich_BehindClosedDoors_1973.harm',
#  'Player_BabyComeBack_1978.harm',
#  'TheBeachBoys_SurfinSafari_1962.harm',
#  'Bread_If_1971.harm',
#  'MilliVanilli_GirlImGonnaMissYou_1989.harm',
#  'Sagittarius_MyWorldFellDown_1967.harm',
#  'YoungMC_BustAMove_1990.harm',
#  'DigitalUnderground_TheHumptyDance_1990.harm',
#  'JanAndDean_TheAnaheimAzusaAndCucamongaSewingCircleBookReviewAndTimingAssociation_1964.harm',
#  'ABBA_OnAndOnAndOn_1981.harm',
#  'Bananarama_ATrickOfTheNight_1987.harm',
#  'RockAndHyde_DirtyWater_1987.harm',
#  'ElvisPresley_MyBoy_1975.harm',
#  'BobSeger_OldTimeRockAndRoll_1979.harm',
#  'BBKing_TheThrillIsGone_1970.harm',
#  'RoyHead_TreatHerRight_1965.harm',
#  'ElvisPresley_Judy_1967.harm',
#  'PatBenatar_FireAndIce_1981.harm',
#  'TheGregKihnBand_HappyMan_1982.harm',
#  'BachmanTurnerOverdrive_Heartaches_1979.harm',
#  'BoDiddley_YouCantJudgeABookByTheCover_1962.harm',
#  'TheEagles_BestOfMyLove_1975.harm',
#  'GaryUSBonds_QuarterToThree_1961.harm',
#  'Sting_AllThisTime_1991.harm',
#  'Badfinger_MaybeTomorrow_1969.harm',
#  'ThePointerSisters_Jump_1984.harm',
#  'BerthaTillman_OhMyAngel_1962.harm',
#  'EricClapton_ForeverMan_1985.harm',
#  'SlyAndTheFamilyStone_IWantToTakeYouHigher_1969.harm',
#  'EttaJames_FoolThatIAm_1961.harm',
#  'JohnnyTillotson_IRiseIFall_1964.harm',
#  'RitaCoolidge_HigherAndHigher_1977.harm',
#  'BBKing_HowBlueCanYouGet_1964.harm',
#  'JimmyJones_HandyMan_1960.harm',
#  'KennyRogers_YouDecoratedMyLife_1980.harm',
#  'LedZeppelin_TrampledUnderFoot_1975.harm',
#  'TheCowsills_Hair_1969.harm',
#  'TheFalcons_IFoundALove_1962.harm',
#  'BoyzIIMen_Motownphilly_1991.harm',
#  'GlenCampbell_Sunflower_1977.harm',
#  'TheRollingStones_TumblingDice_1972.harm',
#  'MelbaMontgomery_NoCharge_1974.harm',
#  'GeorgeBenson_Breezin_1976.harm',
#  'StevieWonder_ThatGirl_1982.harm',
#  'TheJacksons_DancingMachine_1974.harm',
#  'JamesBrown_Think_1973.harm',
#  'CheapTrick_StopThisGame_1980.harm',
#  'FiveManElectricalBand_AbsolutelyRight_1971.harm',
#  'CrosbyStillsAndNash_SouthernCross_1982.harm',
#  'BrendaLee_LosingYou_1963.harm',
#  'DarylHallAndJohnOates_RichGirl_1977.harm',
#  'BuckOwens_IveGotATigerByTheTail_1965.harm',
#  'RitaCoolidge_Fever_1973.harm',
#  'TheDoobieBrothers_EchoesOfLove_1977.harm',
#  'TheMiracles_MightyGoodLovin_1961.harm',
#  'ElvisPresley_ForOlTimesSake_1973.harm',
#  'BrendaLee_DumDum_1961.harm',
#  'BarbaraLewis_HelloStranger_1963.harm',
#  'TalkingHeads_AndSheWas_1985.harm']

# %%
filename_comps = [os.path.splitext(f)[0].split("_") for f in harm_files if os.path.splitext(f)[1] == ".harm"]
files = list({"_".join(f) for f in filename_comps})
files
# Out:
# ['CrosbyStillsAndNash_SuiteJudyBlueEyes_1969',
#  'PetShopBoys_LoveComesQuickly_1986',
#  'SantoAndJohnny_SleepWalk_1959',
#  'MichaelJacksonWithSiedahGarrett_IJustCantStopLovingYou_1987',
#  'The5thDimension_GoWhereYouWannaGo_1967',
#  'BillyIdol_HotInTheCity_1982',
#  'TheCowsills_SilverThreadsAndGoldenNeedles_1969',
#  'NatalieCole_IveGotLoveOnMyMind_1977',
#  'BrownsvilleStation_SmokinInTheBoysRoom_1973',
#  'SlyAndTheFamilyStone_HotFunInTheSummertime_1969',
#  'TheStapleSingers_CityInTheSky_1974',
#  'TheGregKihnBand_Lucky_1985',
#  'FreddyFender_SecretLove_1975',
#  'TheRitchieFamily_TheBestDiscoInTown_1976',
#  'WaylonJennings_AreYouSureHankDoneItThisWay_1975',
#  'JethroTull_LivingInThePast_1972',
#  'ChuckBerry_SweetLittleRockAndRoll_1958',
#  'ArthurConley_SweetSoulMusic_1967',
#  'DonGibson_SeaOfHeartbreak_1961',
#  'CultureClub_IllTumble4Ya_1983',
#  'TheStapleSingers_IllTakeYouThere_1972',
#  'RobertJohn_SadEyes_1979',
#  'EricCarmen_HungryEyes_1988',
#  'BobSeger_EvenNow_1983',
#  'LesleyGore_YouDontOwnMe_1964',
#  'CyndiLauper_IDroveAllNight_1989',
#  'MarvinGayeAndTammiTerrell_IfICouldBuildMyWholeWorldAroundYou_1967',
#  'CrosbyStillsAndNash_SouthernCross_1982',
#  'EddieRabbitt_ILoveARainyNight_1981',
#  'StrayCats_IWontStandInYourWay_1983',
#  'Sagittarius_MyWorldFellDown_1967',
#  'MaryMacGregor_TornBetweenTwoLovers_1976',
#  'RobertJohn_LonelyEyes_1980',
#  'ElvisPresley_ThereGoesMyEverything_1971',
#  'BBKing_HowBlueCanYouGet_1964',
#  'RickJames_GiveItToMeBaby_1981',
#  'JoanBaez_ThereButForFortune_1965',
#  'MelbaMontgomery_NoCharge_1974',
#  'SmokeyRobinson_Cruisin_1980',
#  'EngelbertHumperdinck_AfterTheLovin_1977',
#  'Poison_UnskinnyBop_1990',
#  'ChrisKenner_LandOf1000Dances_1963',
#  'The5thDimension_IDidntGetToSleepAtAll_1972',
#  'TheRollingStones_ItsOnlyRockNRoll_1974',
#  'HiFive_ILikeTheWay_1991',
#  'BeastieBoys_BrassMonkey_1987',
#  'BarryWhite_YoureTheFirstTheLastMyEverything_1974',
#  'AaronNeville_TellItLikeItIs_1966',
#  'TalkingHeads_BurningDownTheHouse_1983',
#  'BobbieGentry_OdeToBillieJoe_1976',
#  'ThePointerSisters_HesSoShy_1980',
#  'BobbyWomack_ThatsTheWayIFeelAboutCha_1971',
#  'LauraBranigan_Gloria_1982',
#  'TinaTurner_WhatYouGetIsWhatYouSee_1987',
#  'TheMoments_WalkRightIn_1963',
#  'Prince_TheArmsOfOrion_1989',
#  'JermaineJackson_LetsGetSerious_1980',
#  'DrHook_TheMillionaire_1975',
#  'JanAndDean_TheAnaheimAzusaAndCucamongaSewingCircleBookReviewAndTimingAssociation_1964',
#  'JacksonBrowne_RedneckFriend_1973',
#  'TheBeachBoys_StillCruisin_1989',
#  'JacksonBrowne_Boulevard_1980',
#  'ClarenceCarter_Patches_1970',
#  'BachmanTurnerOverdrive_Heartaches_1979',
#  'TomTHall_ILove_1973',
#  'SteveWinwood_BackInTheHighLifeAgain_1987',
#  'Madonna_LiveToTell_1986',
#  'Firehouse_DontTreatMeBad_1991',
#  'MartyRobbins_BigIron_1960',
#  'TheMiracles_BabyBabyDontCry_1969',
#  'Wednesday_LastKiss_1974',
#  'BobSeger_RockAndRollNeverForgets_1977',
#  'WangChung_DanceHallDays_1984',
#  'MichaelJackson_HumanNature_1983',
#  'JimmyBuffett_ComeMonday_1974',
#  'Alabama_TakeMeDown_1982',
#  'TalkingHeads_AndSheWas_1985',
#  'TheRollingStones_NotFadeAway_1964',
#  'RitaCoolidge_WereAllAlone_1977',
#  'TheSopwithCamel_HelloHello_1967',
#  'Cher_JustLikeJesseJames_1989',
#  'BrendaLee_AsUsual_1964',
#  'Badfinger_MaybeTomorrow_1969',
#  'BobDylan_GottaServeSomebody_1979',
#  'ElvisPresley_IfICanDream_1968',
#  'PsychedelicFurs_PrettyInPink_1986',
#  'IronButterfly_InAGaddaDaVida_1968',
#  'JohnnyTillotson_OutOfMyMind_1963',
#  'RickSpringfield_DontTalkToStrangers_1982',
#  'TheBabys_EveryTimeIThinkOfYou_1979',
#  'Chicago_AlongComesAWoman_1985',
#  'UrbanDanceSquad_DeeperShadeOfSoul_1991',
#  'TheRollingStones_TumblingDice_1972',
#  'ABBA_OnAndOnAndOn_1981',
#  'ThePowerStation_SomeLikeItHot_1985',
#  'JamesBrown_MyThang_1974',
#  'TheBeachBoys_SailOnSailor_1975',
#  'PeachesAndHerb_ShakeYourGrooveThing_1978',
#  'CountBasie_GoingToChicagoBlues_1958',
#  'TheMiracles_ISecondThatEmotion_1968',
#  'LaVernBaker_SeeSeeRider_1963',
#  'Shannon_LetTheMusicPlay_1984',
#  'BillyJoel_Pressure_1983',
#  'DeanMartin_IWill_1965',
#  'Focus_HocusPocus_1973',
#  'AnneMurray_DaydreamBeliever_1980',
#  'EarthWindAndFire_AfterTheLoveHasGone_1979',
#  'KennyRogers_ScarletFever_1983',
#  'JohnnyTillotson_TalkBackTremblingLips_1963',
#  'MilliVanilli_GirlImGonnaMissYou_1989',
#  'TheContours_DoYouLoveMe_1988',
#  'BillyJoel_AnInnocentMan_1984',
#  'NatKingCole_RamblinRose_1962',
#  'TheAmboyDukes_JourneyToTheCenterOfTheMind_1968',
#  'TheAllmanBrothersBand_StraightFromTheHeart_1981',
#  'RoyOrbison_CrySoftlyLonelyOne_1967',
#  'BrendaLee_AllAloneAmI_1962',
#  'TheBeatles_DoYouWantToKnowASecret_1964',
#  'ElvisPresley_IReallyDontWantToKnow_1970',
#  'RonnieMilsap_IWouldntHaveMissedItForTheWorld_1981',
#  'MichaelSembello_Maniac_1983',
#  'WaylonJennings_ThemeFromTheDukesOfHazzard_1980',
#  'Debarge_TimeWillReveal_1984',
#  'Genesis_TonightTonightTonight_1987',
#  'CharlieRich_BehindClosedDoors_1973',
#  'Genesis_Misunderstanding_1980',
#  'TheEagles_TheLongRun_1980',
#  'BobSeger_AgainstTheWind_1980',
#  'TheGregKihnBand_HappyMan_1982',
#  'DrHook_IfNotYou_1977',
#  'DavidBowie_GoldenYears_1976',
#  'CannedHeat_LetsWorkTogether_1970',
#  'TenYearsAfter_IdLoveToChangeTheWorld_1971',
#  'MeatLoaf_ParadiseByTheDashboardLight_1978',
#  'BuckOwens_IveGotATigerByTheTail_1965',
#  'RayParkerJr_Ghostbusters_1984',
#  'BillyPreston_WithYouImBornAgain_1979',
#  'BillyIdol_FleshForFantasy_1984',
#  'TommyJames_MonyMony_1968',
#  'ABBA_KnowingMeKnowingYou_1977',
#  'BlueCheer_SummertimeBlues_1968',
#  'KennyRogers_IDontNeedYou_1981',
#  'RickSpringfield_JessiesGirl_1981',
#  'TheJackson5_IWantYouBack_1969',
#  'StevieWonder_IfYouReallyLoveMe_1971',
#  'TommyJames_CrystalBluePersuasion_1969',
#  'Boston_FeelinSatisfied_1979',
#  'DigitalUnderground_TheHumptyDance_1990',
#  'DrHook_YearsFromNow_1980',
#  'BillySquier_MyKindaLover_1982',
#  'HueyLewis_IWantANewDrug_1984',
#  'TheMusicMachine_ThePeopleInMe_1967',
#  'EttaJames_WouldItMakeAnyDifferenceToYou_1963',
#  'Cher_IfICouldTurnBackTime_1989',
#  'GaryUSBonds_QuarterToThree_1961',
#  'DollyParton_StartingOverAgain_1980',
#  'TheTeeSet_MaBelleAmie_1970',
#  'LookingGlass_Brandy_1972',
#  'BrendaLee_LosingYou_1963',
#  'PaulMcCartney_Press_1986',
#  'EltonJohn_TheBitchIsBack_1974',
#  'SonnyAndCher_BabyDontGo_1965',
#  'EttaJames_StopTheWedding_1962',
#  'TeddyPendergrass_IDontLoveYouAnymore_1977',
#  'BillySquier_DontSayYouLoveMe_1989',
#  'TheYoungbloods_GetTogether_1969',
#  'TheMusicExplosion_LittleBitOSoul_1967',
#  'DrHook_OnlySixteen_1976',
#  'JacksonBrowne_HereComeThoseTearsAgain_1977',
#  'TheJacksons_DancingMachine_1974',
#  'The5thDimension_OneLessBellToAnswer_1971',
#  'RareEarth_GetReady_1970',
#  'BerthaTillman_OhMyAngel_1962',
#  'RodStewart_TwistinTheNightAway_1987',
#  'DavidCrosbyAndGrahamNash_CarryMe_1975',
#  'MilliVanilli_GirlYouKnowItsTrue_1989',
#  'AnnPeebles_ICantStandTheRain_1973',
#  'WilsonPickett_DontKnockMyLovePt1_1971',
#  'CandiStaton_YoungHeartsRunFree_1976',
#  'Bread_If_1971',
#  'WilsonPickett_ImInLove_1967',
#  'MaxFrostAndTheTroopers_ShapeOfThingsToCome_1968',
#  'RitaCoolidge_TheWayYouDoTheThingsYouDo_1978',
#  'FourTops_StandingInTheShadowsOfLove_1967',
#  'EricClapton_Promises_1978',
#  'GinoVannelli_HurtsToBeInLove_1985',
#  'MarvinGaye_IWantYou_1976',
#  'ElvisPresley_ForOlTimesSake_1973',
#  'PurePrairieLeague_Amie_1975',
#  'GladysKnightAndThePips_LetterFullOfTears_1962',
#  'ShirleyBrown_WomanToWoman_1975',
#  'BonnieRaitt_NickOfTime_1990',
#  'MichaelJackson_WannaBeStartinSomethin_1983',
#  'JeffersonStarship_CountOnMe_1978',
#  'RayCharles_LetsGoGetStoned_1966',
#  'BillySwan_ICanHelp_1974',
#  'TheBuckinghams_KindOfADrag_1967',
#  'TheFireballs_SugarShack_1963',
#  'BuckOwens_ThinkOfMe_1966',
#  'TheDoobieBrothers_EchoesOfLove_1977',
#  'Dion_BornToCry_1962',
#  'NatKingCole_ThoseLazyHazyCrazyDaysOfSummer_1963',
#  'PaulAnka_LoveMeWarmAndTender_1962',
#  'Chicago_OldDays_1975',
#  'JanisJoplin_KozmicBlues_1969',
#  'DarylHallAndJohnOates_Maneater_1983',
#  'MartyRobbins_IWalkAlone_1968',
#  'BetteMidler_TheRose_1980',
#  'Chicago_AnotherRainyDayInNewYorkCity_1976',
#  'Commodores_Still_1980',
#  'RayCharles_TheRightTime_1959',
#  'KrisKristofferson_LovingHerWasEasier_1971',
#  'TheVentures_Perfidia_1960',
#  'TheAlanParsonsProject_EyeInTheSky_1982',
#  'JohnDenver_AnniesSong_1974',
#  'TheBeatles_ShesAWoman_1964',
#  'Switch_TherellNeverBe_1978',
#  'BrendaLee_ComingOnStrong_1966',
#  'JohnnyTillotson_WorriedGuy_1964',
#  'RitaCoolidge_Fever_1973',
#  'BobbiMartin_ILoveYouSo_1965',
#  'WilsonPickett_SoulDanceNumberThree_1967',
#  'ElvisPresley_SheThinksIStillCare_1977',
#  'JimmyRuffin_IvePassedThisWayBefore_1967',
#  'ElvisPresley_HisLatestFlame_1961',
#  'WilsonPickett_IFoundATrueLove_1968',
#  'GladysKnightAndThePips_BabyDontChangeYourMind_1977',
#  'TheCastaways_LiarLiar_1965',
#  'ElvisPresley_AskMe_1964',
#  'Player_BabyComeBack_1978',
#  'DavidBowie_ModernLove_1983',
#  'TheYardbirds_ShapesOfThings_1966',
#  'PaulMcCartney_WithALittleLuck_1978',
#  'RayCharles_CryingTime_1965',
#  'CannedHeat_OnTheRoadAgain_1968',
#  'CrosbyStillsAndNash_GotItMade_1989',
#  'TheRighteousBrothers_SoulAndInspiration_1966',
#  'BrendaLee_TooManyRivers_1965',
#  'ClarenceCarter_TooWeakToFight_1968',
#  'Chicago_MakeMeSmile_1970',
#  'ATasteOfHoney_Sukiyaki_1981',
#  'Foghat_DrivinWheel_1977',
#  'JamesBrown_BabyYoureRight_1961',
#  'KennyRogers_YouDecoratedMyLife_1980',
#  'LittleRiverBand_WeTwo_1983',
#  'PeggyLee_IsThatAllThereIs_1969',
#  'DonnaFargo_Superman_1973',
#  'JohnnyTillotson_ItKeepsRightOnAHurtin_1962',
#  'RayCharles_EleanorRigby_1968',
#  'Sting_AllThisTime_1991',
#  'EltonJohn_Levon_1971',
#  'BillWithers_LovelyDay_1978',
#  'SolomonBurke_IfYouNeedMe_1963',
#  'TheFabulousThunderbirds_TuffEnuff_1986',
#  'PatrickHernandez_BornToBeAlive_1979',
#  'BillyJoel_JustTheWayYouAre_1978',
#  'JohnnyLee_LookinForLove_1980',
#  'MelTorme_CominHomeBaby_1962',
#  'BillWithers_AintNoSunshine_1971',
#  'GinoVannelli_BlackCars_1985',
#  'JeffBeck_PeopleGetReady_1985',
#  'EddieHolland_Jamie_1962',
#  'MarvinGayeAndKimWeston_ItTakesTwo_1967',
#  'Dion_ThisLittleGirl_1963',
#  'WilsonPickett_InTheMidnightHour_1965',
#  'BBKing_TheThrillIsGone_1970',
#  'CoreyHart_InYourSoul_1988',
#  'EricClapton_ForeverMan_1985',
#  'DeanMartin_EverybodyLovesSomebody_1964',
#  'ElvisPresley_MyBoy_1975',
#  'Kaoma_Lambada_1990',
#  'DavidBowie_SpaceOddity_1973',
#  'BrendaLee_HeartInHand_1962',
#  'ArethaFranklin_ChainOfFools_1967',
#  'DrJohn_RightPlaceWrongTime_1973',
#  'TheCowsills_Hair_1969',
#  'LosLobos_WillTheWolfSurvive_1985',
#  'ColorMeBadd_IAdoreMiAmor_1991',
#  'BrendaLee_DumDum_1961',
#  'BobbyBare_DetroitCity_1963',
#  'ChicoDeBarge_TalkToMe_1987',
#  'JimmySmith_WalkOnTheWildSide_1962',
#  'CarlCarlton_EverlastingLove_1974',
#  'GlenCampbell_Sunflower_1977',
#  'RayPrice_ForTheGoodTimes_1970',
#  'TheJGeilsBand_OneLastKiss_1978',
#  'ArethaFranklin_OhMeOhMy_1972',
#  'CyndiLauper_SheBop_1984',
#  'BayCityRollers_SaturdayNight_1975',
#  'JimiHendrix_Freedom_1971',
#  'GlenCampbell_Galveston_1969',
#  'BrotherJackMcDuff_ThemeFromElectricSurfboard_1969',
#  'TheRollingStones_HaveYouSeenYourMotherBabyStandingInTheShadow_1966',
#  'LittleAnthonyAndTheImperials_OutOfSightOutOfMind_1969',
#  'RickDerringer_RockAndRollHoochieKoo_1974',
#  'SwinginMedallions_DoubleShot_1966',
#  'FreddyFender_LivingItDown_1976',
#  'TheBoys_DialMyHeart_1988',
#  'AlanODay_UndercoverAngel_1977',
#  'ElvisPresley_Judy_1967',
#  'JerryReed_KoKoJoe_1971',
#  'TheJGeilsBand_LookingForALove_1972',
#  'BillyIdol_CatchMyFall_1985',
#  'MeatLoaf_YouTookTheWordsRightOutOfMyMouth_1978',
#  'KennyRogers_Lucille_1977',
#  'StevieWonder_ThatGirl_1982',
#  'DuranDuran_IDontWantYourLove_1989',
#  'BobSeger_OldTimeRockAndRoll_1979',
#  'ArethaFranklin_INeverLovedAMan_1967',
#  'TheBeachBoys_Wendy_1964',
#  'GeorgeHarrison_AllThoseYearsAgo_1981',
#  'ABBA_Fernando_1976',
#  'CrosbyStillsAndNash_TeachYourChildren_1970',
#  'ThePolice_SpiritsInTheMaterialWorld_1982',
#  'RandyVanwarmer_JustWhenINeededYouMost_1979',
#  'OtisRedding_ChainedAndBound_1964',
#  'Commodores_Easy_1977',
#  'JimmyJones_HandyMan_1960',
#  'PatBenatar_LittleTooLate_1983',
#  'WillieNelson_BlueEyesCryingInTheRain_1975',
#  'RockAndHyde_DirtyWater_1987',
#  'KennyRogers_ThroughTheYears_1981',
#  'RobertPalmer_AddictedToLove_1986',
#  'Dion_RubyBaby_1963',
#  'TanyaTucker_HeresSomeLove_1976',
#  'DinahWashington_WhereAreYou_1962',
#  'JoeCocker_WithALittleHelpFromMyFriends_1968',
#  'TheEverlyBrothers_OnTheWingsOfANightingale_1984',
#  'The5thDimension_NeverMyLove_1971',
#  'TheByrds_GoinBack_1967',
#  'Snap_ThePower_1990',
#  'MinnieRiperton_LovinYou_1975',
#  'PaulAnka_LetMeGetToKnowYou_1974',
#  'ABBA_TakeAChanceOnMe_1978',
#  'INXS_NeedYouTonight_1988',
#  'TheOJays_LoveTrain_1973',
#  'Sting_IfYouLoveSomebodySetThemFree_1985',
#  'BrendaLee_EverybodyLovesMeButYou_1962',
#  'RobBase_ItTakesTwo_1988',
#  'TheRollingStones_GoingToAGoGo_1982',
#  'ToddRundgren_CanWeStillBeFriends_1978',
#  'UB40_TheWayYouDoTheThingsYouDo_1990',
#  'CliffRichard_DevilWoman_1976',
#  'TheRollingStones_WaitingOnAFriend_1982',
#  'CyndiLauper_AllThroughTheNight_1984',
#  'BobSeger_TryinToLiveMyLifeWithoutYou_1981',
#  'LittleRiverBand_TheOtherGuy_1983',
#  'RoyHead_TreatHerRight_1965',
#  'TheBand_LifeIsACarnival_1971',
#  'EttaJames_FoolThatIAm_1961',
#  'LedZeppelin_TrampledUnderFoot_1975',
#  'KennyRogers_SweetMusicMan_1978',
#  'GrahamNash_Chicago_1971',
#  'IrmaThomas_WishSomeoneWouldCare_1964',
#  'BarbraStreisand_FunnyGirl_1964',
#  'FloydCramer_LastDate_1960',
#  'SteveMillerBand_TheJoker_1973',
#  'TevinCampbell_TellMeWhatYouWantMeToDo_1991',
#  'DuranDuran_AllSheWantsIs_1989',
#  'TheDrifters_OnBroadway_1963',
#  'CliffRichard_Carrie_1980',
#  'ElvisPresley_MyWishCameTrue_1959',
#  'JimmyCliff_WonderfulWorldBeautifulPeople_1969',
#  'PatBenatar_FireAndIce_1981',
#  'TheEverlyBrothers_EbonyEyes_1961',
#  'BobSeger_AmericanStorm_1986',
#  'TheAnimals_SanFranciscanNights_1967',
#  'BenEKing_Amor_1961',
#  'RobertaFlack_FeelLikeMakinLove_1974',
#  'JohnDenver_ItAmazesMe_1978',
#  'SlyAndTheFamilyStone_IWantToTakeYouHigher_1969',
#  'TheOsmonds_OneBadApple_1971',
#  'TheIsleyBrothers_ItsYourThing_1969',
#  'DaveDudley_SixDaysOnTheRoad_1963',
#  'TheDramatics_HeyYouGetOffMyMountain_1973',
#  'Dion_WhereOrWhen_1960',
#  'LouisPrimaAndKeelySmith_ThatOldBlackMagic_1958',
#  'TheByrds_EightMilesHigh_1966',
#  'JacksonBrowne_RunningOnEmpty_1978',
#  'Yaz_Situation_1982',
#  'BobbyWomack_SweetCaroline_1972',
#  'TheEagles_BestOfMyLove_1975',
#  'JohnnyTillotson_IRiseIFall_1964',
#  'TheCrystals_TheresNoOther_1961',
#  'CheapTrick_Surrender_1978',
#  'IsaacHayes_TheLookOfLove_1971',
#  'TinaTurner_PrivateDancer_1985',
#  'Chicago_AliveAgain_1978',
#  'TheRollingStones_DooDooDooDooDoo_1974',
#  'TheTemptations_AintTooProudToBeg_1966',
#  'StrayCats_RockThisTown_1982',
#  'EltonJohn_PhiladelphiaFreedom_1975',
#  'MichaelJackson_ManInTheMirror_1988',
#  'JohnDenver_SomeDaysAreDiamonds_1981',
#  'BonniePointer_HeavenMustHaveSentYou_1979',
#  'CharlieRich_LonelyWeekends_1960',
#  'DianaRoss_UpsideDown_1980',
#  'DrHook_WalkRightIn_1977',
#  'BJThomas_HookedOnAFeeling_1968',
#  'DarylHallAndJohnOates_RichGirl_1977',
#  'TheYardbirds_HeartFullOfSoul_1965',
#  'ThePointerSisters_Jump_1984',
#  'NickGilder_HotChildInTheCity_1978',
#  'TheStringALongs_Wheels_1961',
#  'MichaelJohnson_AlmostLikeBeingInLove_1978',
#  'SammyHagar_GiveToLive_1987',
#  'SonnyAndCher_ACowboysWorkIsNeverDone_1972',
#  'BoyzIIMen_Motownphilly_1991',
#  'BarbraStreisand_People_1964',
#  'DollyParton_BabyImBurnin_1979',
#  'RitaCoolidge_HigherAndHigher_1977',
#  'YvonneElliman_IfICantHaveYou_1978',
#  'NenehCherry_KissesOnTheWind_1989',
#  'EvelynChampagneKing_ImInLove_1981',
#  'Dion_LoveCameToMe_1962',
#  'Boston_Amanda_1986',
#  'DeLaSoul_MeMyselfAndI_1989',
#  'DoubleExposure_TenPercent_1976',
#  'AnitaBaker_GivingYouTheBestThatIGot_1989',
#  'CheapTrick_IWantYouToWantMe_1979',
#  'ToddRundgren_ADreamGoesOnForever_1974',
#  'SteveWinwood_DontYouKnowWhatTheNightCanDo_1988',
#  'RobertaFlackAndDonnyHathaway_YouveGotAFriend_1971',
#  'TheSupremes_FloyJoy_1972',
#  'TomTHall_TheYearThatClaytonDelaneyDied_1971',
#  'TheBoxTops_CryLikeABaby_1968',
#  'GoldenEarring_TwilightZone_1983',
#  'JesusJones_RightHereRightNow_1991',
#  'PaulSimon_YouCanCallMeAl_1986',
#  'TracyChapman_BabyCanIHoldYou_1989',
#  'TheRollingStones_Dandelion_1967',
#  'GlenCampbell_ItsOnlyMakeBelieve_1970',
#  'CharlieRich_AVerySpecialLoveSong_1974',
#  'MarcCohn_WalkingInMemphis_1991',
#  'Redbone_ComeAndGetYourLove_1974',
#  'RodStewart_MaggieMay_1971',
#  'YoungMC_BustAMove_1990',
#  'JamesBrown_Think_1973',
#  'TheCure_JustLikeHeaven_1988',
#  'Aerosmith_LastChild_1976',
#  'Baltimora_TarzanBoy_1986',
#  'TheBeatles_IDontWantToSpoilTheParty_1965',
#  'SimonAndGarfunkel_FakinIt_1967',
#  'EdgarWinter_Frankenstein_1973',
#  'BoDiddley_YouCantJudgeABookByTheCover_1962',
#  'GladysKnightAndThePips_IfIWereYourWoman_1971',
#  'TheMiracles_MightyGoodLovin_1961',
#  'GlenCampbell_RhinestoneCowboy_1975',
#  'DottieWest_ALessonInLeavin_1980',
#  'LittleRiverBand_HappyAnniversary_1978',
#  'DarylHallAndJohnOates_SaraSmile_1976',
#  'Genesis_InvisibleTouch_1986',
#  'BobSeger_NightMoves_1977',
#  'Ocean_PutYourHandInTheHand_1971',
#  'Bread_SweetSurrender_1972',
#  'TracieSpencer_ThisHouse_1990',
#  'FlattAndScruggs_FoggyMountainBreakdown_1968',
#  'TheBeachBoys_BluebirdsOverTheMountain_1969',
#  'EarthWindAndFire_Getaway_1976',
#  'NatalieCole_Unforgettable_1991',
#  'CheapTrick_StopThisGame_1980',
#  'BadCompany_RockNRollFantasy_1979',
#  'BobbyDarin_IfIWereACarpenter_1966',
#  'MarthaAndTheVandellas_NowhereToRun_1965',
#  'FreddieJackson_HaveYouEverLovedSomebody_1987',
#  'JamesTaylor_CountryRoad_1971',
#  'NittyGrittyDirtBand_MakeALittleMagic_1980',
#  'RodBernard_ThisShouldGoOnForever_1959',
#  'GlenCampbell_WichitaLineman_1969',
#  'Blondie_IslandOfLostSouls_1982',
#  'TheFalcons_IFoundALove_1962',
#  'GeorgeHarrison_ThisSong_1977',
#  'Dion_LoversWhoWander_1962',
#  'TheSupremes_StonedLove_1970',
#  'ThePolice_EveryLittleThingSheDoesIsMagic_1981',
#  'ElvisPresley_MyWay_1978',
#  'FatsDomino_IWantToWalkYouHome_1959',
#  'KennyRogers_Lady_1980',
#  'Bananarama_ATrickOfTheNight_1987',
#  'EmersonLakeAndPalmer_LuckyMan_1971',
#  'GladysKnightAndThePips_BestThingThatEverHappenedToMe_1974',
#  'RoxyMusic_DanceAway_1979',
#  'TheJGeilsBand_MustOfGotLost_1974',
#  'Heart_TheresTheGirl_1988',
#  'AliceCooper_HeyStoopid_1991',
#  'StevieWonder_HigherGround_1973',
#  'RDeanTaylor_IndianaWantsMe_1970',
#  'JamesBrown_DownAndOutInNewYorkCity_1973',
#  'PatBenatar_LoveIsABattlefield_1983',
#  'TheTemptations_IWishItWouldRain_1968',
#  'ZZTop_LaGrange_1974',
#  'KateBush_RunningUpThatHill_1985',
#  'NeilSedaka_BreakingUpIsHardToDo_1976',
#  'RoyDrusky_ThreeHeartsInATangle_1961',
#  'CliffRichard_DaddysHome_1982',
#  'WillieMitchell_2075_1964',
#  'JackieWilson_BabyWorkout_1963',
#  'TheJGeilsBand_JustCantWait_1980',
#  'ThelmaHouston_DontLeaveMeThisWay_1977',
#  'LittleJoeyAndTheFlips_BongoStomp_1962',
#  'JuiceNewton_BreakItToMeGently_1982',
#  'IsaacHayes_DoYourThing_1972',
#  'PaperLace_TheNightChicagoDied_1974',
#  'Dion_RunaroundSue_1961',
#  'WildCherry_PlayThatFunkyMusic_1976',
#  'JohnnyTillotson_JimmysGirl_1961',
#  'Commodores_ThreeTimesALady_1978',
#  'GeneralPublic_Tenderness_1984',
#  'MarieOsmond_PaperRoses_1973',
#  'EricClapton_ICantStandIt_1981',
#  'OtisRedding_IveBeenLovingYouTooLong_1965',
#  'GeorgeBenson_Breezin_1976',
#  'TheBeachBoys_SurfinSafari_1962',
#  'Dion_AbrahamMartinAndJohn_1968',
#  'GrandFunkRailroad_WalkLikeAMan_1973',
#  'RunDMC_WalkThisWay_1986',
#  'BarbaraLewis_HelloStranger_1963',
#  'TheHollies_LongDarkRoad_1972',
#  'StevieWonder_DoIDo_1982',
#  'IkeAndTinaTurner_ItsGonnaWorkOutFine_1961',
#  'PatBenatar_PromisesInTheDark_1981',
#  'PetShopBoys_WhereTheStreetsHaveNoName_1991',
#  'IkeAndTinaTurner_IWantToTakeYouHigher_1970',
#  'FiveManElectricalBand_AbsolutelyRight_1971',
#  'GordonLightfoot_Beautiful_1972']

# %%
TIMESTAMP_PATH = '../Resources/Timestamps/'
timestamped_files = [file for file in glob.glob(TIMESTAMP_PATH+'*.hum')]

# %%
timestamped_files
# Out:
# ['../Resources/Timestamps/timestamped_TheTurtles_HappyTogether_1967.hum',
#  '../Resources/Timestamps/timestamped_TheKinks_BetterThings_1981.hum',
#  '../Resources/Timestamps/timestamped_Queensryche_SilentLucidity_1991.hum',
#  '../Resources/Timestamps/timestamped_ChuckBerry_ReelinAndRockin_1972.hum',
#  '../Resources/Timestamps/timestamped_PaulMcCartney_MaybeImAmazed_1977.hum',
#  '../Resources/Timestamps/timestamped_RogerMiller_YouCantRollerSkateInABuffaloHerd_1966.hum',
#  '../Resources/Timestamps/timestamped_Steppenwolf_BornToBeWild_1968.hum',
#  '../Resources/Timestamps/timestamped_TinaTurner_WeDontNeedAnotherHero_1985.hum',
#  '../Resources/Timestamps/timestamped_TheRollingStones_TimeIsOnMySide_1964.hum',
#  '../Resources/Timestamps/timestamped_LedZeppelin_DyerMaker_1973.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_ISawHerStandingThere_1964.hum',
#  '../Resources/Timestamps/timestamped_Level42_SomethingAboutYou_1986.hum',
#  '../Resources/Timestamps/timestamped_TinaTurner_TheBest_1989.hum',
#  '../Resources/Timestamps/timestamped_BingCrosby_SilentNight_1960.hum',
#  '../Resources/Timestamps/timestamped_GratefulDead_SugarMagnolia_1973.hum',
#  '../Resources/Timestamps/timestamped_CliffRichard_WeDontTalkAnymore_1979.hum',
#  '../Resources/Timestamps/timestamped_PaulMcCartneyAndWings_MyLove_1973.hum',
#  '../Resources/Timestamps/timestamped_JamesBrown_IDontMind_1961.hum',
#  '../Resources/Timestamps/timestamped_LindaRonstadt_WhenWillIBeLoved_1975.hum',
#  '../Resources/Timestamps/timestamped_SteveMillerBand_RocknMe_1976.hum',
#  '../Resources/Timestamps/timestamped_JohnDenver_SeasonsOfTheHeart_1982.hum',
#  '../Resources/Timestamps/timestamped_JamesBrown_GetUp_1970.hum',
#  '../Resources/Timestamps/timestamped_TheKendalls_HeavensJustASinAway_1977.hum',
#  '../Resources/Timestamps/timestamped_ABBA_Chiquitita_1979.hum',
#  '../Resources/Timestamps/timestamped_TheRascals_PeopleGotToBeFree_1968.hum',
#  '../Resources/Timestamps/timestamped_WilsonPhillips_HoldOn_1990.hum',
#  '../Resources/Timestamps/timestamped_Metallica_One_1989.hum',
#  '../Resources/Timestamps/timestamped_JoniMitchell_BabyIDontCare_1982.hum',
#  '../Resources/Timestamps/timestamped_TheDoors_RidersOnTheStorm_1971.hum',
#  '../Resources/Timestamps/timestamped_JFrankWilsonAndTheCavaliers_LastKiss_1964.hum',
#  '../Resources/Timestamps/timestamped_JudasPriest_YouveGotAnotherThingComin_1982.hum',
#  '../Resources/Timestamps/timestamped_GeorgeHarrison_BlowAway_1979.hum',
#  '../Resources/Timestamps/timestamped_AnitaBaker_SweetLove_1986.hum',
#  '../Resources/Timestamps/timestamped_VillagePeople_InTheNavy_1979.hum',
#  '../Resources/Timestamps/timestamped_TheChiffons_HesSoFine_1963.hum',
#  '../Resources/Timestamps/timestamped_TinaTurner_WhatsLoveGotToDoWithIt_1984.hum',
#  '../Resources/Timestamps/timestamped_ChuckBerry_AlmostGrown_1959.hum',
#  '../Resources/Timestamps/timestamped_SpandauBallet_True_1983.hum',
#  '../Resources/Timestamps/timestamped_TheMiracles_IDontBlameYouAtAll_1971.hum',
#  '../Resources/Timestamps/timestamped_DinahWashington_Unforgettable_1959.hum',
#  '../Resources/Timestamps/timestamped_JimmyClanton_JustADream_1958.hum',
#  '../Resources/Timestamps/timestamped_JohnnyCash_IGotStripes_1959.hum',
#  '../Resources/Timestamps/timestamped_EricClapton_LetItRain_1972.hum',
#  '../Resources/Timestamps/timestamped_JamesBrown_IGotYou_1965.hum',
#  '../Resources/Timestamps/timestamped_BruceChannel_HeyBaby_1962.hum',
#  '../Resources/Timestamps/timestamped_LynyrdSkynyrd_SweetHomeAlabama_1974.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_ComeTogether_1969.hum',
#  '../Resources/Timestamps/timestamped_PeggyLee_Fever_1958.hum',
#  '../Resources/Timestamps/timestamped_TheRollingStones_WildHorses_1971.hum',
#  '../Resources/Timestamps/timestamped_TheWho_PinballWizard_1969.hum',
#  '../Resources/Timestamps/timestamped_MichaelJackson_BeatIt_1983.hum',
#  '../Resources/Timestamps/timestamped_LaVernBaker_ICriedATear_1959.hum',
#  '../Resources/Timestamps/timestamped_SimonAndGarfunkel_MrsRobinson_1968.hum',
#  '../Resources/Timestamps/timestamped_EltonJohn_WhoWearsTheseShoes_1984.hum',
#  '../Resources/Timestamps/timestamped_TheRembrandts_Someone_1991.hum',
#  '../Resources/Timestamps/timestamped_SonnyAndCher_AllIEverNeedIsYou_1971.hum',
#  '../Resources/Timestamps/timestamped_JamesBrown_ColdSweatPart1_1967.hum',
#  '../Resources/Timestamps/timestamped_ChubbyChecker_TheTwist_1962.hum',
#  '../Resources/Timestamps/timestamped_FatsDomino_BeMyGuest_1959.hum',
#  '../Resources/Timestamps/timestamped_SoftCell_TaintedLove_1982.hum',
#  '../Resources/Timestamps/timestamped_EdwinStarr_War_1970.hum',
#  '../Resources/Timestamps/timestamped_ElvisPresley_GuitarMan_1968.hum',
#  '../Resources/Timestamps/timestamped_ThePolice_DontStandSoCloseToMe_1981.hum',
#  '../Resources/Timestamps/timestamped_Queen_WeAreTheChampions_1978.hum',
#  '../Resources/Timestamps/timestamped_SimonAndGarfunkel_ElCondorPasa_1970.hum',
#  '../Resources/Timestamps/timestamped_TheBeachBoys_InMyRoom_1963.hum',
#  '../Resources/Timestamps/timestamped_HarryChapin_SundayMorningSunshine_1972.hum',
#  '../Resources/Timestamps/timestamped_CultureClub_KarmaChameleon_1984.hum',
#  '../Resources/Timestamps/timestamped_DarylHallAndJohnOates_KissOnMyList_1981.hum',
#  '../Resources/Timestamps/timestamped_EricClapton_LayDownSally_1978.hum',
#  '../Resources/Timestamps/timestamped_DavidRuffinAndJimmyRuffin_StandByMe_1970.hum',
#  '../Resources/Timestamps/timestamped_ElvisPresley_LittleSister_1961.hum',
#  '../Resources/Timestamps/timestamped_Genesis_Abacab_1982.hum',
#  '../Resources/Timestamps/timestamped_Commodores_Lady_1981.hum',
#  '../Resources/Timestamps/timestamped_JohnDenver_RockyMountainHigh_1972.hum',
#  '../Resources/Timestamps/timestamped_Chicago_25Or6To4_1970.hum',
#  '../Resources/Timestamps/timestamped_CreedenceClearwaterRevival_BadMoonRising_1969.hum',
#  '../Resources/Timestamps/timestamped_StevieB_BecauseILoveYou_1991.hum',
#  '../Resources/Timestamps/timestamped_CyndiLauper_TheGooniesRGoodEnough_1985.hum',
#  '../Resources/Timestamps/timestamped_GinoVannelli_WildHorses_1987.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_Help_1965.hum',
#  '../Resources/Timestamps/timestamped_Oliver_GoodMorningStarshine_1969.hum',
#  '../Resources/Timestamps/timestamped_PaulRevereAndTheRaiders_Kicks_1966.hum',
#  '../Resources/Timestamps/timestamped_TheRobertCrayBand_SmokingGun_1987.hum',
#  '../Resources/Timestamps/timestamped_BillyJoel_DontAskMeWhy_1980.hum',
#  '../Resources/Timestamps/timestamped_OakRidgeBoys_Elvira_1981.hum',
#  '../Resources/Timestamps/timestamped_MilliVanilli_BabyDontForgetMyNumber_1989.hum',
#  '../Resources/Timestamps/timestamped_The5thDimension_IfICouldReachYou_1972.hum',
#  '../Resources/Timestamps/timestamped_AnneMurray_LoveSong_1974.hum',
#  '../Resources/Timestamps/timestamped_TheTrammps_DiscoInferno_1977.hum',
#  '../Resources/Timestamps/timestamped_TheRollingStones_HonkyTonkWomen_1969.hum',
#  '../Resources/Timestamps/timestamped_EltonJohn_GoodbyeYellowBrickRoad_1973.hum',
#  '../Resources/Timestamps/timestamped_AndyGibb_ShadowDancing_1978.hum',
#  '../Resources/Timestamps/timestamped_JanAndDean_TheLittleOldLady_1964.hum',
#  '../Resources/Timestamps/timestamped_LittleRiverBand_Reminiscing_1978.hum',
#  '../Resources/Timestamps/timestamped_Chicago_DoesAnybodyReallyKnowWhatTimeItIs_1970.hum',
#  '../Resources/Timestamps/timestamped_CheapTrick_DreamPolice_1979.hum',
#  '../Resources/Timestamps/timestamped_CorneliusBrothersAndSisterRose_TreatHerLikeALady_1971.hum',
#  '../Resources/Timestamps/timestamped_LittleRiverBand_HelpIsOnItsWay_1977.hum',
#  '../Resources/Timestamps/timestamped_TheWeatherGirls_ItsRainingMen_1983.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_EightDaysAWeek_1965.hum',
#  '../Resources/Timestamps/timestamped_MarkyMark_GoodVibrations_1991.hum',
#  '../Resources/Timestamps/timestamped_TheEagles_AlreadyGone_1974.hum',
#  '../Resources/Timestamps/timestamped_GloriaGaynor_NeverCanSayGoodbye_1975.hum',
#  '../Resources/Timestamps/timestamped_Whitesnake_HereIGoAgain_1987.hum',
#  '../Resources/Timestamps/timestamped_EricCarmen_Sunrise_1976.hum',
#  '../Resources/Timestamps/timestamped_BruceSpringsteen_ImGoinDown_1985.hum',
#  '../Resources/Timestamps/timestamped_Chicago_FeelinStrongerEveryDay_1973.hum',
#  '../Resources/Timestamps/timestamped_Heart_WhoWillYouRunTo_1987.hum',
#  '../Resources/Timestamps/timestamped_KoolAndTheGang_JungleBoogie_1974.hum',
#  '../Resources/Timestamps/timestamped_Heart_MagicMan_1976.hum',
#  '../Resources/Timestamps/timestamped_TheMeters_LookKaPyPy_1970.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_ObLaDiObLaDa_1976.hum',
#  '../Resources/Timestamps/timestamped_Wham_WakeMeUpBeforeYouGoGo_1984.hum',
#  '../Resources/Timestamps/timestamped_HankSnow_IveBeenEverywhere_1962.hum',
#  '../Resources/Timestamps/timestamped_TheShirelles_WillYouLoveMeTomorrow_1961.hum',
#  '../Resources/Timestamps/timestamped_PinkFloyd_Money_1973.hum',
#  '../Resources/Timestamps/timestamped_DrHook_SexyEyes_1980.hum',
#  '../Resources/Timestamps/timestamped_JerryJeffWalker_MrBojangles_1968.hum',
#  '../Resources/Timestamps/timestamped_TheEverlyBrothers_WalkRightBack_1961.hum',
#  '../Resources/Timestamps/timestamped_BillyIdol_RebelYell_1984.hum',
#  '../Resources/Timestamps/timestamped_JohnDenver_BackHomeAgain_1974.hum',
#  '../Resources/Timestamps/timestamped_TheEagles_LyinEyes_1975.hum',
#  '../Resources/Timestamps/timestamped_TheRollingStones_MissYou_1978.hum',
#  '../Resources/Timestamps/timestamped_TheJGeilsBand_FreezeFrame_1982.hum',
#  '../Resources/Timestamps/timestamped_JuiceNewton_QueenOfHearts_1981.hum',
#  '../Resources/Timestamps/timestamped_NakedEyes_AlwaysSomethingThereToRemindMe_1983.hum',
#  '../Resources/Timestamps/timestamped_U2_WithOrWithoutYou_1987.hum',
#  '../Resources/Timestamps/timestamped_PeterGabriel_ShockTheMonkey_1982.hum',
#  '../Resources/Timestamps/timestamped_BillyIdol_WhiteWedding_1983.hum',
#  '../Resources/Timestamps/timestamped_AnneMurray_CouldIHaveThisDance_1980.hum',
#  '../Resources/Timestamps/timestamped_PaulSimon_50WaysToLeaveYourLover_1976.hum',
#  '../Resources/Timestamps/timestamped_UB40_RedRedWine_1984.hum',
#  '../Resources/Timestamps/timestamped_FontellaBass_RescueMe_1965.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_LoveMeDo_1964.hum',
#  '../Resources/Timestamps/timestamped_DepecheMode_WorldInMyEyes_1990.hum',
#  '../Resources/Timestamps/timestamped_GeorgeHarrison_GotMyMindSetOnYou_1988.hum',
#  '../Resources/Timestamps/timestamped_PetShopBoys_WhatHaveIDoneToDeserveThis_1988.hum',
#  '../Resources/Timestamps/timestamped_TheRonettes_BeMyBaby_1963.hum',
#  '../Resources/Timestamps/timestamped_CyndiLauper_TrueColors_1986.hum',
#  '../Resources/Timestamps/timestamped_TheRighteousBrothers_UnchainedMelody_1965.hum',
#  '../Resources/Timestamps/timestamped_BruceSpringsteen_MyHometown_1985.hum',
#  '../Resources/Timestamps/timestamped_TheChiffons_SweetTalkinGuy_1966.hum',
#  '../Resources/Timestamps/timestamped_RickJames_SuperFreak_1981.hum',
#  '../Resources/Timestamps/timestamped_Santana_EvilWays_1970.hum',
#  '../Resources/Timestamps/timestamped_MarvinGaye_MercyMercyMe_1971.hum',
#  '../Resources/Timestamps/timestamped_TheBeatles_AHardDaysNight_1964.hum',
#  '../Resources/Timestamps/timestamped_LedZeppelin_OverTheHillsAndFarAway_1973.hum',
#  '../Resources/Timestamps/timestamped_NittyGrittyDirtBand_BuyForMeTheRain_1967.hum',
#  '../Resources/Timestamps/timestamped_EricClapton_WillieAndTheHandJive_1974.hum',
#  '../Resources/Timestamps/timestamped_Cream_SunshineOfYourLove_1968.hum',
#  '../Resources/Timestamps/timestamped_TheWho_HappyJack_1967.hum',
#  '../Resources/Timestamps/timestamped_Kiss_RocketRide_1978.hum',
#  '../Resources/Timestamps/timestamped_DavidBowie_BlueJean_1984.hum',
#  '../Resources/Timestamps/timestamped_SimonAndGarfunkel_TheSoundsOfSilence_1965.hum',
#  '../Resources/Timestamps/timestamped_TheBeachBoys_Kokomo_1988.hum',
#  '../Resources/Timestamps/timestamped_GenePitney_TownWithoutPity_1961.hum',
#  '../Resources/Timestamps/timestamped_BingCrosby_WhiteChristmas_1962.hum',
#  '../Resources/Timestamps/timestamped_JanAndDean_SidewalkSurfin_1964.hum',
#  '../Resources/Timestamps/timestamped_TheCrystals_HesARebel_1962.hum',
#  '../Resources/Timestamps/timestamped_SimonAndGarfunkel_AHazyShadeOfWinter_1966.hum',
#  '../Resources/Timestamps/timestamped_JimmyReed_BabyWhatYouWantMeToDo_1960.hum',
#  '../Resources/Timestamps/timestamped_StephanieMills_NeverKnewLoveLikeThisBefore_1980.hum',
#  '../Resources/Timestamps/timestamped_AlGreen_OhMeOhMy_1975.hum',
#  '../Resources/Timestamps/timestamped_TheElectricPrunes_IHadTooMuchToDream_1967.hum',
#  '../Resources/Timestamps/timestamped_CliffRichard_LivingDoll_1959.hum',
#  '../Resources/Timestamps/timestamped_VanHalen_WhenItsLove_1988.hum',
#  '../Resources/Timestamps/timestamped_JohnnyHorton_JohnnyReb_1959.hum',
#  '../Resources/Timestamps/timestamped_Bananarama_Venus_1986.hum',
#  '../Resources/Timestamps/timestamped_TheLas_ThereSheGoes_1991.hum',
#  '../Resources/Timestamps/timestamped_ElvisPresley_OneNight_1959.hum',
#  '../Resources/Timestamps/timestamped_BachmanTurnerOverdrive_RollOnDownTheHighway_1975.hum',
#  '../Resources/Timestamps/timestamped_PinkFloyd_AnotherBrickInTheWall_1980.hum',
#  '../Resources/Timestamps/timestamped_PatBenatar_Heartbreaker_1980.hum',
#  '../Resources/Timestamps/timestamped_Madonna_OhFather_1990.hum',
#  '../Resources/Timestamps/timestamped_BobSeger_LikeARock_1986.hum',
#  '../Resources/Timestamps/timestamped_Rush_TheSpiritOfRadio_1980.hum',
#  '../Resources/Timestamps/timestamped_AliceCooper_SchoolsOut_1972.hum',
#  '../Resources/Timestamps/timestamped_CreedenceClearwaterRevival_IPutASpellOnYou_1968.hum',
#  '../Resources/Timestamps/timestamped_TheHollies_CarrieAnne_1967.hum',
#  '../Resources/Timestamps/timestamped_JohnnyCash_TheWaysOfAWomanInLove_1958.hum',
#  '../Resources/Timestamps/timestamped_JoniMitchell_BigYellowTaxi_1975.hum',
#  '../Resources/Timestamps/timestamped_Quarterflash_HardenMyHeart_1982.hum',
#  '../Resources/Timestamps/timestamped_LeoSayer_YouMakeMeFeelLikeDancing_1977.hum',
#  '../Resources/Timestamps/timestamped_BrendaLee_SweetNothins_1960.hum',
#  '../Resources/Timestamps/timestamped_SimonAndGarfunkel_Cecilia_1970.hum',
#  '../Resources/Timestamps/timestamped_Commodores_Nightshift_1985.hum',
#  '../Resources/Timestamps/timestamped_NancySinatra_TheseBootsAreMadeForWalkin_1966.hum',
#  '../Resources/Timestamps/timestamped_Donovan_SunshineSuperman_1966.hum',
#  '../Resources/Timestamps/timestamped_Blondie_OneWayOrAnother_1979.hum',
#  '../Resources/Timestamps/timestamped_BillySquier_TheStroke_1981.hum',
#  '../Resources/Timestamps/timestamped_DuranDuran_IsThereSomethingIShouldKnow_1983.hum',
#  '../Resources/Timestamps/timestamped_BizMarkie_JustAFriend_1990.hum',
#  '../Resources/Timestamps/timestamped_REOSpeedwagon_TimeForMeToFly_1980.hum',
#  '../Resources/Timestamps/timestamped_Heart_CrazyOnYou_1978.hum',
#  '../Resources/Timestamps/timestamped_JohnnyHorton_TheBattleOfNewOrleans_1959.hum',
#  '../Resources/Timestamps/timestamped_Rockwell_SomebodysWatchingMe_1984.hum',
#  '../Resources/Timestamps/timestamped_TomJones_ShesALady_1971.hum',
#  '../Resources/Timestamps/timestamped_DonnaSummer_LastDance_1978.hum',
#  '../Resources/Timestamps/timestamped_PetShopBoys_AlwaysOnMyMind_1988.hum',
#  '../Resources/Timestamps/timestamped_SammyHagar_ICantDrive55_1984.hum',
#  '../Resources/Timestamps/timestamped_SimpleMinds_SanctifyYourself_1986.hum',
#  '../Resources/Timestamps/timestamped_GeorgeHarrison_CrackerboxPalace_1977.hum',
#  '../Resources/Timestamps/timestamped_TheEverlyBrothers_ThatsOldFashioned_1962.hum',
#  '../Resources/Timestamps/timestamped_LesleyGore_CaliforniaNights_1967.hum',
#  '../Resources/Timestamps/timestamped_TheEverlyBrothers_BirdDog_1958.hum',
#  '../Resources/Timestamps/timestamped_ABBA_HoneyHoney_1974.hum',
#  '../Resources/Timestamps/timestamped_AnitaBaker_CaughtUpInTheRapture_1987.hum',
#  '../Resources/Timestamps/timestamped_LouisArmstrong_HelloDolly_1964.hum',
#  '../Resources/Timestamps/timestamped_Roxette_TheLook_1989.hum',
#  '../Resources/Timestamps/timestamped_EarthWindAndFire_September_1979.hum',
#  '../Resources/Timestamps/timestamped_TheKinks_TillTheEndOfTheDay_1966.hum',
#  '../Resources/Timestamps/timestamped_OtisRedding_TheDockOfTheBay_1968.hum',
#  '../Resources/Timestamps/timestamped_PhilCollins_TwoHearts_1989.hum']

# %%
os.chdir("../../../CoCoPops-Clone/Billboard/Data/")

# %%
os.getcwd()
# Out:
# '/Users/johnmcnamara/Documents/GitHub/CoCoPops-Clone/Billboard/Data'

# %%
def createHarte(song):
    
    humFile = song+'.harm'
    df = pd.read_csv(humFile, sep = "\t")
    
#     timestamp_hum = TIMESTAMP_PATH+"timestamped_"+song+".hum" # Humdrum File containing Nat's interpolated timestamps, and nothing else
#     timestampdf = pd.read_csv(timestamp_hum)
    
    chordsym = df["**chordsym"].copy()
    harmony = df["**harmony"].copy()
    df["**harte"] = chordsym
#     df["**timestamp"] = timestamp_hum["**harmony"]
    matches = chordsym.str.extractall(r'(^[A-G][-#]?)').dropna()
    match_indicies = list(set([matches.index[i][0] for i in range(len(matches.index))]))
    match_indicies.sort()
    proto_harte = chordsym.str.extract("(^[A-G][-#]?:?\w*\(?[^A-G ]*\)?)").dropna()
    for i in match_indicies:
        notes = matches.loc[i][0]
        if len(notes) > 1:
            bass_interval = calc_interval(notes[0], notes[1])
            bass_interval = "" if bass_interval == "1" else "/" + bass_interval
            proto_harte.loc[i][0] =  proto_harte.loc[i][0] + bass_interval

    for i in proto_harte.index[1:]:
        chordsym.loc[i] = proto_harte.loc[i][0]

    df["**harte"] = chordsym
#     df = df.drop(["**chordsym"], axis = 1)
    df = df[["**harmony", "**harte", "**timestamp", "**phrase", "**leadinstrument"]]
    df.to_csv("ConvertedHarmFiles/"+humFile, sep="\t", index=False)
    return df

# %%
pd.read_csv(harm_files[0], sep = "\t")
# Out:
#                                              **harmony **chordsym   **phrase  \
# 0                                                *M4/4      *M4/4          *
# 1                                                  *D:        *D:          *
# 2                                                  1r;          r          .
# 3                                                   =1         =1         =1
# 4                                            *>C_intro  *>C_intro  *>C_intro
# ..                                                 ...        ...        ...
# 327  !!!RDF**timestamp: McGill audio timestamp in s...        NaN        NaN
# 328  !!!RDF**leadinstrument: original McGill primar...        NaN        NaN
# 329                                !!!RDT: 2017/01/12/        NaN        NaN
# 330                   !!!ENC: Nathaniel Condit-Schultz        NaN        NaN
# 331  !!!EST: Awating manual error checking and edit...        NaN        NaN
#
#     **timestamp **leadinstrument
# 0             *                *
# 1             *                *
# 2             0                r
# 3            =1               =1
# 4     *>C_intro        *>C_intro
# ..          ...              ...
# 327         NaN              NaN
# 328         NaN              NaN
# 329         NaN              NaN
# 330         NaN              NaN
# 331         NaN              NaN
#
# [332 rows x 5 columns]

# %%
createHarte(files[1])
# Out:
#                                              **harmony    **harte **timestamp  \
# 0                                                *M4/4      *M4/4           *
# 1                                                  *b:        *b:         *b:
# 2                                                  1r;          r           0
# 3                                                   =1         =1          =1
# 4                                            *>A_intro  *>A_intro   *>A_intro
# ..                                                 ...        ...         ...
# 274  !!!RDF**timestamp: McGill audio timestamp in s...        NaN         NaN
# 275  !!!RDF**leadinstrument: original McGill primar...        NaN         NaN
# 276                                !!!RDT: 2017/01/12/        NaN         NaN
# 277                   !!!ENC: Nathaniel Condit-Schultz        NaN         NaN
# 278  !!!EST: Awating manual error checking and edit...        NaN         NaN
#
#       **phrase **leadinstrument
# 0            *                *
# 1          *b:              *b:
# 2            .                r
# 3           =1               =1
# 4    *>A_intro        *>A_intro
# ..         ...              ...
# 274        NaN              NaN
# 275        NaN              NaN
# 276        NaN              NaN
# 277        NaN              NaN
# 278        NaN              NaN
#
# [279 rows x 5 columns]

# %%
for file in files:
    createHarte(file)

# %%
pd.read_csv("../Resources/Timestamps/")
